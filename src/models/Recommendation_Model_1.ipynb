# %%
import pandas as pd
import numpy as np

# %%
# ------------------------------------------------
# SAMPLE DATA WITH STOCK
# ------------------------------------------------
data = [
{
    "Manufacturer_id": "M001",
    "Manufacturer_name": "UrbanWood Creations",
    "Manufacturer_address": "12 Timber Industrial Park",
    "Manufacturer_State": "Karnataka",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "Sofa",
    "Product_Id": "FUR001",
    "Product_Name": "UrbanWood 3-Seater Sofa",
    "Product_Description": "Premium fabric 3-seater sofa with wooden frame",
    "Unit_Price": 520.00,
    "Current_Stock": 110,
    "Lead_time_days": 9,
    "Total_orders": 340,
    "Total_units_supplied": 2900,
    "Return_Units": 40,
    "Response_Time_in_hrs": 12,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "M002",
    "Manufacturer_name": "RoyalHome Interiors",
    "Manufacturer_address": "45 Furniture Estate",
    "Manufacturer_State": "Maharashtra",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "Dining Table",
    "Product_Id": "FUR002",
    "Product_Name": "RoyalHome 4-Seater Dining Set",
    "Product_Description": "Solid wood dining table with 4 chairs",
    "Unit_Price": 650.00,
    "Current_Stock": 85,
    "Lead_time_days": 10,
    "Total_orders": 220,
    "Total_units_supplied": 1700,
    "Return_Units": 28,
    "Response_Time_in_hrs": 14,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "M003",
    "Manufacturer_name": "ComfortNest Furnishings",
    "Manufacturer_address": "88 Home Decor Hub",
    "Manufacturer_State": "Tamil Nadu",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "Bed",
    "Product_Id": "FUR003",
    "Product_Name": "ComfortNest Queen Bed",
    "Product_Description": "Queen size wooden bed with storage",
    "Unit_Price": 580.00,
    "Current_Stock": 95,
    "Lead_time_days": 8,
    "Total_orders": 260,
    "Total_units_supplied": 2100,
    "Return_Units": 35,
    "Response_Time_in_hrs": 13,
    "Ratings": 4.5
  },

  {
    "Manufacturer_id": "M004",
    "Manufacturer_name": "EliteLiving Spaces",
    "Manufacturer_address": "101 Interior Park",
    "Manufacturer_State": "Delhi",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "Wardrobe",
    "Product_Id": "FUR004",
    "Product_Name": "EliteLiving 2-Door Wardrobe",
    "Product_Description": "Compact wardrobe with laminated finish",
    "Unit_Price": 420.00,
    "Current_Stock": 75,
    "Lead_time_days": 9,
    "Total_orders": 190,
    "Total_units_supplied": 1500,
    "Return_Units": 25,
    "Response_Time_in_hrs": 15,
    "Ratings": 4.4
  },

  {
    "Manufacturer_id": "M005",
    "Manufacturer_name": "WoodCraft Industries",
    "Manufacturer_address": "67 Timber Street",
    "Manufacturer_State": "Gujarat",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "Coffee Table",
    "Product_Id": "FUR005",
    "Product_Name": "WoodCraft Glass Coffee Table",
    "Product_Description": "Modern coffee table with glass top",
    "Unit_Price": 210.00,
    "Current_Stock": 140,
    "Lead_time_days": 6,
    "Total_orders": 410,
    "Total_units_supplied": 3600,
    "Return_Units": 60,
    "Response_Time_in_hrs": 10,
    "Ratings": 4.3
  },

  {
    "Manufacturer_id": "M006",
    "Manufacturer_name": "UrbanWood Creations",
    "Manufacturer_address": "12 Timber Industrial Park",
    "Manufacturer_State": "Karnataka",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "Office Chair",
    "Product_Id": "FUR006",
    "Product_Name": "UrbanWood Ergonomic Chair",
    "Product_Description": "Ergonomic office chair with lumbar support",
    "Unit_Price": 180.00,
    "Current_Stock": 200,
    "Lead_time_days": 7,
    "Total_orders": 520,
    "Total_units_supplied": 4700,
    "Return_Units": 85,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.5
  },

  {
    "Manufacturer_id": "M007",
    "Manufacturer_name": "RoyalHome Interiors",
    "Manufacturer_address": "45 Furniture Estate",
    "Manufacturer_State": "Maharashtra",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "Bookshelf",
    "Product_Id": "FUR007",
    "Product_Name": "RoyalHome 5-Tier Bookshelf",
    "Product_Description": "Spacious wooden bookshelf with 5 shelves",
    "Unit_Price": 300.00,
    "Current_Stock": 130,
    "Lead_time_days": 8,
    "Total_orders": 350,
    "Total_units_supplied": 3100,
    "Return_Units": 55,
    "Response_Time_in_hrs": 12,
    "Ratings": 4.6
  },

  {
    "Manufacturer_id": "M008",
    "Manufacturer_name": "ComfortNest Furnishings",
    "Manufacturer_address": "88 Home Decor Hub",
    "Manufacturer_State": "Tamil Nadu",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "Recliner",
    "Product_Id": "FUR008",
    "Product_Name": "ComfortNest Leather Recliner",
    "Product_Description": "Premium recliner chair with footrest",
    "Unit_Price": 480.00,
    "Current_Stock": 60,
    "Lead_time_days": 10,
    "Total_orders": 180,
    "Total_units_supplied": 1400,
    "Return_Units": 22,
    "Response_Time_in_hrs": 16,
    "Ratings": 4.8
  },

  {
    "Manufacturer_id": "M009",
    "Manufacturer_name": "EliteLiving Spaces",
    "Manufacturer_address": "101 Interior Park",
    "Manufacturer_State": "Delhi",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "TV Unit",
    "Product_Id": "FUR009",
    "Product_Name": "EliteLiving Modern TV Stand",
    "Product_Description": "Wooden TV unit with storage cabinets",
    "Unit_Price": 390.00,
    "Current_Stock": 110,
    "Lead_time_days": 9,
    "Total_orders": 270,
    "Total_units_supplied": 2200,
    "Return_Units": 40,
    "Response_Time_in_hrs": 13,
    "Ratings": 4.7
  },

  {
    "Manufacturer_id": "M010",
    "Manufacturer_name": "WoodCraft Industries",
    "Manufacturer_address": "67 Timber Street",
    "Manufacturer_State": "Gujarat",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "Study Table",
    "Product_Id": "FUR010",
    "Product_Name": "WoodCraft Study Desk",
    "Product_Description": "Compact study table with drawers",
    "Unit_Price": 250.00,
    "Current_Stock": 170,
    "Lead_time_days": 7,
    "Total_orders": 390,
    "Total_units_supplied": 3400,
    "Return_Units": 65,
    "Response_Time_in_hrs": 11,
    "Ratings": 4.5
  },

{
    "Manufacturer_id": "MF101",
    "Manufacturer_name": "GreenOak Furnitures",
    "Manufacturer_address": "221 Woodline Avenue",
    "Manufacturer_State": "Rajasthan",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "Modular Sofa",
    "Product_Id": "F101",
    "Product_Name": "GreenOak L-Shape Modular Sofa",
    "Product_Description": "Convertible L-shape modular sofa with washable covers",
    "Unit_Price": 780.00,
    "Current_Stock": 60,
    "Lead_time_days": 14,
    "Total_orders": 180,
    "Total_units_supplied": 1450,
    "Return_Units": 18,
    "Response_Time_in_hrs": 20,
    "Ratings": 4.8
  },
  {
    "Manufacturer_id": "MF102",
    "Manufacturer_name": "PrimeEdge Interiors",
    "Manufacturer_address": "78 Decor Street",
    "Manufacturer_State": "Telangana",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "Dining Chair",
    "Product_Id": "F102",
    "Product_Name": "PrimeEdge Upholstered Dining Chair",
    "Product_Description": "Ergonomic cushioned dining chair set of 2",
    "Unit_Price": 140.00,
    "Current_Stock": 200,
    "Lead_time_days": 6,
    "Total_orders": 520,
    "Total_units_supplied": 4800,
    "Return_Units": 72,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "MF103",
    "Manufacturer_name": "CasaCraft Studio",
    "Manufacturer_address": "305 Heritage Road",
    "Manufacturer_State": "Kerala",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "Wooden Cot",
    "Product_Id": "F103",
    "Product_Name": "CasaCraft Teak Wooden Cot",
    "Product_Description": "Handcrafted teak wood cot with headboard design",
    "Unit_Price": 890.00,
    "Current_Stock": 40,
    "Lead_time_days": 18,
    "Total_orders": 140,
    "Total_units_supplied": 980,
    "Return_Units": 12,
    "Response_Time_in_hrs": 24,
    "Ratings": 4.9
  },
  {
    "Manufacturer_id": "MF104",
    "Manufacturer_name": "MetroLiving Furnish",
    "Manufacturer_address": "19 Urban Plaza",
    "Manufacturer_State": "Uttar Pradesh",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "Shoe Rack",
    "Product_Id": "F104",
    "Product_Name": "MetroLiving 4-Tier Shoe Rack",
    "Product_Description": "Compact engineered wood shoe storage rack",
    "Unit_Price": 95.00,
    "Current_Stock": 320,
    "Lead_time_days": 5,
    "Total_orders": 880,
    "Total_units_supplied": 7600,
    "Return_Units": 130,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.2
  },
  {
    "Manufacturer_id": "MF105",
    "Manufacturer_name": "OakVista Designs",
    "Manufacturer_address": "502 Craft Industrial Area",
    "Manufacturer_State": "Punjab",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "Center Table",
    "Product_Id": "F105",
    "Product_Name": "OakVista Marble Center Table",
    "Product_Description": "Premium marble top center table with metal frame",
    "Unit_Price": 450.00,
    "Current_Stock": 75,
    "Lead_time_days": 11,
    "Total_orders": 260,
    "Total_units_supplied": 2100,
    "Return_Units": 26,
    "Response_Time_in_hrs": 16,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "MF106",
    "Manufacturer_name": "NeoHome Creations",
    "Manufacturer_address": "14 Modern Park",
    "Manufacturer_State": "Haryana",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "Office Desk",
    "Product_Id": "F106",
    "Product_Name": "NeoHome Executive Office Desk",
    "Product_Description": "Spacious executive office desk with cable management",
    "Unit_Price": 520.00,
    "Current_Stock": 90,
    "Lead_time_days": 9,
    "Total_orders": 310,
    "Total_units_supplied": 2700,
    "Return_Units": 40,
    "Response_Time_in_hrs": 13,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "MF107",
    "Manufacturer_name": "SkyLine Furnitures",
    "Manufacturer_address": "61 Skyline Avenue",
    "Manufacturer_State": "Odisha",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "Revolving Chair",
    "Product_Id": "F107",
    "Product_Name": "SkyLine Mesh Revolving Chair",
    "Product_Description": "Breathable mesh back revolving office chair",
    "Unit_Price": 210.00,
    "Current_Stock": 180,
    "Lead_time_days": 7,
    "Total_orders": 640,
    "Total_units_supplied": 5900,
    "Return_Units": 95,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.3
  },
  {
    "Manufacturer_id": "MF108",
    "Manufacturer_name": "RusticRoots Furnish",
    "Manufacturer_address": "88 Artisan Street",
    "Manufacturer_State": "Madhya Pradesh",
    "Product_Category": "Furniture",
    "Prouct_sub_Category": "Books Cabinet",
    "Product_Id": "F108",
    "Product_Name": "RusticRoots Solid Wood Cabinet",
    "Product_Description": "Solid wood cabinet with glass doors",
    "Unit_Price": 620.00,
    "Current_Stock": 55,
    "Lead_time_days": 12,
    "Total_orders": 190,
    "Total_units_supplied": 1500,
    "Return_Units": 20,
    "Response_Time_in_hrs": 18,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "L001",
    "Manufacturer_name": "GlowTech Lighting",
    "Manufacturer_address": "12 Illumination Park",
    "Manufacturer_State": "Maharashtra",
    "Product_Category": "Lights",
    "Prouct_sub_Category": "LED Bulb",
    "Product_Id": "LG001",
    "Product_Name": "GlowTech 9W Eco LED",
    "Product_Description": "Energy efficient 9W LED bulb for home use",
    "Unit_Price": 4.50,
    "Current_Stock": 8500,
    "Lead_time_days": 3,
    "Total_orders": 1400,
    "Total_units_supplied": 18000,
    "Return_Units": 260,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "L002",
    "Manufacturer_name": "BrightAura Industries",
    "Manufacturer_address": "45 Spark Estate",
    "Manufacturer_State": "Gujarat",
    "Product_Category": "Lights",
    "Prouct_sub_Category": "Ceiling Light",
    "Product_Id": "LG002",
    "Product_Name": "BrightAura Crystal Ceiling Lamp",
    "Product_Description": "Decorative crystal ceiling light for living rooms",
    "Unit_Price": 75.00,
    "Current_Stock": 420,
    "Lead_time_days": 7,
    "Total_orders": 380,
    "Total_units_supplied": 3200,
    "Return_Units": 48,
    "Response_Time_in_hrs": 12,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "L003",
    "Manufacturer_name": "NovaBeam Solutions",
    "Manufacturer_address": "88 Light Hub",
    "Manufacturer_State": "Tamil Nadu",
    "Product_Category": "Lights",
    "Prouct_sub_Category": "Street Light",
    "Product_Id": "LG003",
    "Product_Name": "NovaBeam Solar Street Pro",
    "Product_Description": "Solar powered street light with motion sensor",
    "Unit_Price": 210.00,
    "Current_Stock": 260,
    "Lead_time_days": 10,
    "Total_orders": 190,
    "Total_units_supplied": 1500,
    "Return_Units": 22,
    "Response_Time_in_hrs": 18,
    "Ratings": 4.8
  },
  {
    "Manufacturer_id": "L004",
    "Manufacturer_name": "SkyGlow Lighting",
    "Manufacturer_address": "101 Horizon Road",
    "Manufacturer_State": "Delhi",
    "Product_Category": "Lights",
    "Prouct_sub_Category": "Table Lamp",
    "Product_Id": "LG004",
    "Product_Name": "SkyGlow Touch Desk Lamp",
    "Product_Description": "Touch control LED table lamp with dimming feature",
    "Unit_Price": 32.00,
    "Current_Stock": 1200,
    "Lead_time_days": 5,
    "Total_orders": 720,
    "Total_units_supplied": 6400,
    "Return_Units": 110,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.5
  },

  {
    "Manufacturer_id": "L005",
    "Manufacturer_name": "RadiantEdge Pvt Ltd",
    "Manufacturer_address": "67 Industrial Avenue",
    "Manufacturer_State": "Karnataka",
    "Product_Category": "Lights",
    "Prouct_sub_Category": "Panel Light",
    "Product_Id": "LG005",
    "Product_Name": "RadiantEdge Slim Panel 18W",
    "Product_Description": "Slim round LED panel light for offices",
    "Unit_Price": 22.00,
    "Current_Stock": 3400,
    "Lead_time_days": 4,
    "Total_orders": 980,
    "Total_units_supplied": 11000,
    "Return_Units": 190,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.3
  },

  {
    "Manufacturer_id": "L006",
    "Manufacturer_name": "LumaCore Lighting",
    "Manufacturer_address": "19 Energy Park",
    "Manufacturer_State": "Telangana",
    "Product_Category": "Lights",
    "Prouct_sub_Category": "Flood Light",
    "Product_Id": "LG006",
    "Product_Name": "LumaCore Outdoor Flood 50W",
    "Product_Description": "Waterproof 50W LED flood light",
    "Unit_Price": 45.00,
    "Current_Stock": 1500,
    "Lead_time_days": 6,
    "Total_orders": 610,
    "Total_units_supplied": 5800,
    "Return_Units": 95,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.6
  },

  {
    "Manufacturer_id": "L007",
    "Manufacturer_name": "UrbanLite Systems",
    "Manufacturer_address": "222 Metro Industrial Zone",
    "Manufacturer_State": "Rajasthan",
    "Product_Category": "Lights",
    "Prouct_sub_Category": "Chandelier",
    "Product_Id": "LG007",
    "Product_Name": "UrbanLite Royal Chandelier",
    "Product_Description": "Luxury crystal chandelier for banquet halls",
    "Unit_Price": 320.00,
    "Current_Stock": 140,
    "Lead_time_days": 12,
    "Total_orders": 150,
    "Total_units_supplied": 1100,
    "Return_Units": 15,
    "Response_Time_in_hrs": 20,
    "Ratings": 4.9
  },

  {
    "Manufacturer_id": "L008",
    "Manufacturer_name": "EcoGlow Industries",
    "Manufacturer_address": "75 Green Energy Street",
    "Manufacturer_State": "Kerala",
    "Product_Category": "Lights",
    "Prouct_sub_Category": "Garden Light",
    "Product_Id": "LG008",
    "Product_Name": "EcoGlow Solar Garden Stick",
    "Product_Description": "Solar powered decorative garden light",
    "Unit_Price": 18.00,
    "Current_Stock": 2900,
    "Lead_time_days": 4,
    "Total_orders": 870,
    "Total_units_supplied": 9200,
    "Return_Units": 140,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "LP001",
    "Manufacturer_name": "TechNova Systems",
    "Manufacturer_address": "12 Silicon Park",
    "Manufacturer_State": "Karnataka",
    "Product_Category": "Laptops",
    "Prouct_sub_Category": "Gaming Laptop",
    "Product_Id": "LT001",
    "Product_Name": "TechNova Predator X15",
    "Product_Description": "High performance gaming laptop with RTX graphics",
    "Unit_Price": 1450.00,
    "Current_Stock": 120,
    "Lead_time_days": 7,
    "Total_orders": 420,
    "Total_units_supplied": 3500,
    "Return_Units": 85,
    "Response_Time_in_hrs": 10,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "LP002",
    "Manufacturer_name": "SkyByte Technologies",
    "Manufacturer_address": "45 Tech Valley",
    "Manufacturer_State": "Maharashtra",
    "Product_Category": "Laptops",
    "Prouct_sub_Category": "Business Laptop",
    "Product_Id": "LT002",
    "Product_Name": "SkyByte ProBook 14",
    "Product_Description": "Lightweight business laptop with long battery life",
    "Unit_Price": 980.00,
    "Current_Stock": 210,
    "Lead_time_days": 5,
    "Total_orders": 680,
    "Total_units_supplied": 5400,
    "Return_Units": 110,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "LP003",
    "Manufacturer_name": "Zenith Electronics",
    "Manufacturer_address": "88 Innovation Hub",
    "Manufacturer_State": "Tamil Nadu",
    "Product_Category": "Laptops",
    "Prouct_sub_Category": "Student Laptop",
    "Product_Id": "LT003",
    "Product_Name": "Zenith EduLite 15",
    "Product_Description": "Affordable student laptop with SSD storage",
    "Unit_Price": 620.00,
    "Current_Stock": 340,
    "Lead_time_days": 4,
    "Total_orders": 950,
    "Total_units_supplied": 8800,
    "Return_Units": 160,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.3
  },
  {
    "Manufacturer_id": "LP004",
    "Manufacturer_name": "CoreWave Devices",
    "Manufacturer_address": "19 Digital Estate",
    "Manufacturer_State": "Delhi",
    "Product_Category": "Laptops",
    "Prouct_sub_Category": "Ultrabook",
    "Product_Id": "LT004",
    "Product_Name": "CoreWave SlimEdge X",
    "Product_Description": "Ultra-thin ultrabook with AMOLED display",
    "Unit_Price": 1320.00,
    "Current_Stock": 95,
    "Lead_time_days": 6,
    "Total_orders": 410,
    "Total_units_supplied": 3300,
    "Return_Units": 70,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "LP005",
    "Manufacturer_name": "NextGen Circuits",
    "Manufacturer_address": "67 Silicon Street",
    "Manufacturer_State": "Gujarat",
    "Product_Category": "Laptops",
    "Prouct_sub_Category": "2-in-1 Convertible",
    "Product_Id": "LT005",
    "Product_Name": "NextGen FlexiBook",
    "Product_Description": "Convertible laptop with touchscreen and stylus support",
    "Unit_Price": 1100.00,
    "Current_Stock": 150,
    "Lead_time_days": 6,
    "Total_orders": 520,
    "Total_units_supplied": 4100,
    "Return_Units": 90,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.4
  },

  {
    "Manufacturer_id": "LP006",
    "Manufacturer_name": "OrbitTech Innovations",
    "Manufacturer_address": "201 Future Park",
    "Manufacturer_State": "Telangana",
    "Product_Category": "Laptops",
    "Prouct_sub_Category": "Workstation Laptop",
    "Product_Id": "LT006",
    "Product_Name": "OrbitTech RenderPro 17",
    "Product_Description": "Powerful workstation laptop for designers",
    "Unit_Price": 2100.00,
    "Current_Stock": 60,
    "Lead_time_days": 9,
    "Total_orders": 240,
    "Total_units_supplied": 1900,
    "Return_Units": 35,
    "Response_Time_in_hrs": 12,
    "Ratings": 4.8
  },

  {
    "Manufacturer_id": "LP007",
    "Manufacturer_name": "ByteCraft Systems",
    "Manufacturer_address": "77 Techno Plaza",
    "Manufacturer_State": "Punjab",
    "Product_Category": "Laptops",
    "Prouct_sub_Category": "Chromebook",
    "Product_Id": "LT007",
    "Product_Name": "ByteCraft ChromeLite",
    "Product_Description": "Secure Chromebook for everyday tasks",
    "Unit_Price": 450.00,
    "Current_Stock": 420,
    "Lead_time_days": 3,
    "Total_orders": 1020,
    "Total_units_supplied": 9400,
    "Return_Units": 180,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.2
  },

  {
    "Manufacturer_id": "LP008",
    "Manufacturer_name": "FusionCore Technologies",
    "Manufacturer_address": "305 Digital Tower",
    "Manufacturer_State": "Haryana",
    "Product_Category": "Laptops",
    "Prouct_sub_Category": "Budget Laptop",
    "Product_Id": "LT008",
    "Product_Name": "FusionCore ValueBook",
    "Product_Description": "Entry-level laptop with Intel i3 processor",
    "Unit_Price": 520.00,
    "Current_Stock": 380,
    "Lead_time_days": 4,
    "Total_orders": 880,
    "Total_units_supplied": 7600,
    "Return_Units": 150,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.1
  },
  {
    "Manufacturer_id": "LP009",
    "Manufacturer_name": "QuantumEdge Tech",
    "Manufacturer_address": "14 Infinity Park",
    "Manufacturer_State": "Kerala",
    "Product_Category": "Laptops",
    "Prouct_sub_Category": "Gaming Laptop",
    "Product_Id": "LT009",
    "Product_Name": "QuantumEdge Titan G17",
    "Product_Description": "Advanced gaming laptop with RGB keyboard",
    "Unit_Price": 1750.00,
    "Current_Stock": 85,
    "Lead_time_days": 8,
    "Total_orders": 310,
    "Total_units_supplied": 2600,
    "Return_Units": 60,
    "Response_Time_in_hrs": 11,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "LP010",
    "Manufacturer_name": "AeroByte Electronics",
    "Manufacturer_address": "91 SkyTech Street",
    "Manufacturer_State": "Odisha",
    "Product_Category": "Laptops",
    "Prouct_sub_Category": "Business Laptop",
    "Product_Id": "LT010",
    "Product_Name": "AeroByte Executive 13",
    "Product_Description": "Compact business laptop with fingerprint security",
    "Unit_Price": 1020.00,
    "Current_Stock": 140,
    "Lead_time_days": 5,
    "Total_orders": 560,
    "Total_units_supplied": 4800,
    "Return_Units": 95,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "LP011",
    "Manufacturer_name": "Vertex Digital",
    "Manufacturer_address": "33 Innovation Square",
    "Manufacturer_State": "Rajasthan",
    "Product_Category": "Laptops",
    "Prouct_sub_Category": "Ultrabook",
    "Product_Id": "LT011",
    "Product_Name": "Vertex AirLite X",
    "Product_Description": "Feather-light ultrabook with metal body",
    "Unit_Price": 1250.00,
    "Current_Stock": 110,
    "Lead_time_days": 6,
    "Total_orders": 470,
    "Total_units_supplied": 3900,
    "Return_Units": 75,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "LP012",
    "Manufacturer_name": "InfiCore Systems",
    "Manufacturer_address": "55 Circuit Avenue",
    "Manufacturer_State": "West Bengal",
    "Product_Category": "Laptops",
    "Prouct_sub_Category": "Student Laptop",
    "Product_Id": "LT012",
    "Product_Name": "InfiCore StudyMate 14",
    "Product_Description": "Affordable laptop ideal for students",
    "Unit_Price": 580.00,
    "Current_Stock": 360,
    "Lead_time_days": 4,
    "Total_orders": 990,
    "Total_units_supplied": 8700,
    "Return_Units": 170,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.2
  },
  {
    "Manufacturer_id": "LP013",
    "Manufacturer_name": "PrimeLogic Devices",
    "Manufacturer_address": "72 Digital Park",
    "Manufacturer_State": "Uttar Pradesh",
    "Product_Category": "Laptops",
    "Prouct_sub_Category": "Workstation Laptop",
    "Product_Id": "LT013",
    "Product_Name": "PrimeLogic Creator Pro 16",
    "Product_Description": "High-end laptop for video editing and 3D work",
    "Unit_Price": 1980.00,
    "Current_Stock": 70,
    "Lead_time_days": 9,
    "Total_orders": 230,
    "Total_units_supplied": 1800,
    "Return_Units": 40,
    "Response_Time_in_hrs": 13,
    "Ratings": 4.8
  },
  {
    "Manufacturer_id": "R001",
    "Manufacturer_name": "GoldenGrain Mills",
    "Manufacturer_address": "12 Agro Industrial Park",
    "Manufacturer_State": "Punjab",
    "Product_Category": "Rice",
    "Product_sub_Category": "Basmati Rice",
    "Product_Id": "RC001",
    "Product_Name": "GoldenGrain Premium Basmati 5kg",
    "Product_Description": "Long grain aromatic basmati rice aged 1 year",
    "Unit_Price": 18.50,
    "Current_Stock": 5200,
    "Lead_time_days": 4,
    "Total_orders": 1400,
    "Total_units_supplied": 18500,
    "Return_Units": 210,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "R002",
    "Manufacturer_name": "FarmFresh Agro",
    "Manufacturer_address": "45 Harvest Road",
    "Manufacturer_State": "Haryana",
    "Product_Category": "Rice",
    "Product_sub_Category": "Sona Masoori",
    "Product_Id": "RC002",
    "Product_Name": "FarmFresh Sona Masoori 10kg",
    "Product_Description": "Medium grain sona masoori rice for daily cooking",
    "Unit_Price": 22.00,
    "Current_Stock": 6300,
    "Lead_time_days": 3,
    "Total_orders": 1650,
    "Total_units_supplied": 21000,
    "Return_Units": 260,
    "Response_Time_in_hrs": 5,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "R003",
    "Manufacturer_name": "PureHarvest Foods",
    "Manufacturer_address": "88 Grain Market",
    "Manufacturer_State": "Telangana",
    "Product_Category": "Rice",
    "Product_sub_Category": "Brown Rice",
    "Product_Id": "RC003",
    "Product_Name": "PureHarvest Organic Brown Rice 5kg",
    "Product_Description": "Healthy organic brown rice with high fiber content",
    "Unit_Price": 25.50,
    "Current_Stock": 4100,
    "Lead_time_days": 5,
    "Total_orders": 980,
    "Total_units_supplied": 12400,
    "Return_Units": 120,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "R004",
    "Manufacturer_name": "AgriGold Exports",
    "Manufacturer_address": "19 Export Zone",
    "Manufacturer_State": "Andhra Pradesh",
    "Product_Category": "Rice",
    "Product_sub_Category": "Raw Rice",
    "Product_Id": "RC004",
    "Product_Name": "AgriGold Raw Rice 25kg",
    "Product_Description": "High quality raw rice for bulk cooking",
    "Unit_Price": 40.00,
    "Current_Stock": 3500,
    "Lead_time_days": 6,
    "Total_orders": 720,
    "Total_units_supplied": 9800,
    "Return_Units": 140,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.3
  },
  {
    "Manufacturer_id": "R005",
    "Manufacturer_name": "NatureField Organics",
    "Manufacturer_address": "77 Green Valley Road",
    "Manufacturer_State": "Karnataka",
    "Product_Category": "Rice",
    "Product_sub_Category": "Organic Rice",
    "Product_Id": "RC005",
    "Product_Name": "NatureField Organic White Rice 5kg",
    "Product_Description": "Chemical-free organic white rice",
    "Unit_Price": 27.00,
    "Current_Stock": 2800,
    "Lead_time_days": 5,
    "Total_orders": 860,
    "Total_units_supplied": 10500,
    "Return_Units": 95,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.8
  },

  {
    "Manufacturer_id": "R006",
    "Manufacturer_name": "Shakti Grains",
    "Manufacturer_address": "14 Rural Agro Park",
    "Manufacturer_State": "West Bengal",
    "Product_Category": "Rice",
    "Product_sub_Category": "Parboiled Rice",
    "Product_Id": "RC006",
    "Product_Name": "Shakti Parboiled Rice 10kg",
    "Product_Description": "Premium parboiled rice suitable for daily meals",
    "Unit_Price": 20.00,
    "Current_Stock": 4600,
    "Lead_time_days": 4,
    "Total_orders": 1200,
    "Total_units_supplied": 15000,
    "Return_Units": 175,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.5
  },

  {
    "Manufacturer_id": "R007",
    "Manufacturer_name": "RoyalFields Agro",
    "Manufacturer_address": "23 Farming Estate",
    "Manufacturer_State": "Odisha",
    "Product_Category": "Rice",
    "Product_sub_Category": "Basmati Rice",
    "Product_Id": "RC007",
    "Product_Name": "RoyalFields Classic Basmati 1kg",
    "Product_Description": "Fine aromatic basmati rice for special dishes",
    "Unit_Price": 5.20,
    "Current_Stock": 8200,
    "Lead_time_days": 3,
    "Total_orders": 2100,
    "Total_units_supplied": 26000,
    "Return_Units": 310,
    "Response_Time_in_hrs": 5,
    "Ratings": 4.6
  },

  {
    "Manufacturer_id": "R008",
    "Manufacturer_name": "SunHarvest Foods",
    "Manufacturer_address": "66 Agro Export Street",
    "Manufacturer_State": "Uttar Pradesh",
    "Product_Category": "Rice",
    "Product_sub_Category": "Jeera Rice",
    "Product_Id": "RC008",
    "Product_Name": "SunHarvest Jeera Rice 5kg",
    "Product_Description": "Small grain jeera rice ideal for biryani",
    "Unit_Price": 19.80,
    "Current_Stock": 3900,
    "Lead_time_days": 4,
    "Total_orders": 980,
    "Total_units_supplied": 12100,
    "Return_Units": 140,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "R009",
    "Manufacturer_name": "AgroPure Mills",
    "Manufacturer_address": "102 Grain Corridor",
    "Manufacturer_State": "Bihar",
    "Product_Category": "Rice",
    "Product_sub_Category": "Brown Rice",
    "Product_Id": "RC009",
    "Product_Name": "AgroPure Healthy Brown 2kg",
    "Product_Description": "Unpolished brown rice rich in nutrients",
    "Unit_Price": 11.50,
    "Current_Stock": 5100,
    "Lead_time_days": 4,
    "Total_orders": 760,
    "Total_units_supplied": 9800,
    "Return_Units": 130,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "R010",
    "Manufacturer_name": "EverGreen Agro Foods",
    "Manufacturer_address": "19 Harvest Lane",
    "Manufacturer_State": "Madhya Pradesh",
    "Product_Category": "Rice",
    "Product_sub_Category": "Raw Rice",
    "Product_Id": "RC010",
    "Product_Name": "EverGreen Raw Rice 5kg",
    "Product_Description": "Premium quality raw rice for traditional meals",
    "Unit_Price": 17.20,
    "Current_Stock": 4400,
    "Lead_time_days": 5,
    "Total_orders": 830,
    "Total_units_supplied": 10500,
    "Return_Units": 145,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.3
  },
  {
    "Manufacturer_id": "R011",
    "Manufacturer_name": "Krishna Grains",
    "Manufacturer_address": "33 Paddy Market",
    "Manufacturer_State": "Chhattisgarh",
    "Product_Category": "Rice",
    "Product_sub_Category": "Parboiled Rice",
    "Product_Id": "RC011",
    "Product_Name": "Krishna Parboiled Classic 25kg",
    "Product_Description": "High volume parboiled rice for catering use",
    "Unit_Price": 42.00,
    "Current_Stock": 2800,
    "Lead_time_days": 6,
    "Total_orders": 540,
    "Total_units_supplied": 7600,
    "Return_Units": 95,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "R012",
    "Manufacturer_name": "HealthyHarvest Co.",
    "Manufacturer_address": "71 Organic Street",
    "Manufacturer_State": "Kerala",
    "Product_Category": "Rice",
    "Product_sub_Category": "Organic Rice",
    "Product_Id": "RC012",
    "Product_Name": "HealthyHarvest Organic Red Rice 5kg",
    "Product_Description": "Traditional organic red rice rich in antioxidants",
    "Unit_Price": 29.50,
    "Current_Stock": 3100,
    "Lead_time_days": 5,
    "Total_orders": 720,
    "Total_units_supplied": 9300,
    "Return_Units": 110,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "R013",
    "Manufacturer_name": "PaddyKing Industries",
    "Manufacturer_address": "58 Rice Export Road",
    "Manufacturer_State": "Tamil Nadu",
    "Product_Category": "Rice",
    "Product_sub_Category": "Basmati Rice",
    "Product_Id": "RC013",
    "Product_Name": "PaddyKing Supreme Basmati 10kg",
    "Product_Description": "Extra-long grain aged basmati rice",
    "Unit_Price": 36.00,
    "Current_Stock": 3900,
    "Lead_time_days": 4,
    "Total_orders": 1180,
    "Total_units_supplied": 14900,
    "Return_Units": 205,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "R014",
    "Manufacturer_name": "Annapurna Agro Mills",
    "Manufacturer_address": "11 Village Agro Park",
    "Manufacturer_State": "Jharkhand",
    "Product_Category": "Rice",
    "Product_sub_Category": "Sona Masoori",
    "Product_Id": "RC014",
    "Product_Name": "Annapurna Premium Sona 5kg",
    "Product_Description": "Fine quality sona masoori rice",
    "Unit_Price": 16.80,
    "Current_Stock": 4700,
    "Lead_time_days": 4,
    "Total_orders": 960,
    "Total_units_supplied": 12200,
    "Return_Units": 155,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "R015",
    "Manufacturer_name": "FarmGold Exports",
    "Manufacturer_address": "87 Agro Trade Center",
    "Manufacturer_State": "Haryana",
    "Product_Category": "Rice",
    "Product_sub_Category": "Jeera Rice",
    "Product_Id": "RC015",
    "Product_Name": "FarmGold Jeera Select 2kg",
    "Product_Description": "Small grain aromatic jeera rice",
    "Unit_Price": 8.40,
    "Current_Stock": 6500,
    "Lead_time_days": 3,
    "Total_orders": 1540,
    "Total_units_supplied": 18900,
    "Return_Units": 270,
    "Response_Time_in_hrs": 5,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "PIP001",
    "Manufacturer_name": "FlowMaster Industries",
    "Manufacturer_address": "12 Industrial Estate",
    "Manufacturer_State": "Gujarat",
    "Product_Category": "Pipes",
    "Prouct_sub_Category": "PVC Pipe",
    "Product_Id": "PP001",
    "Product_Name": "FlowMaster PVC 1 inch",
    "Product_Description": "High pressure PVC pipe suitable for water supply",
    "Unit_Price": 12.50,
    "Current_Stock": 8500,
    "Lead_time_days": 4,
    "Total_orders": 1400,
    "Total_units_supplied": 18000,
    "Return_Units": 220,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "PIP002",
    "Manufacturer_name": "AquaLine Pipes",
    "Manufacturer_address": "45 Pipeline Road",
    "Manufacturer_State": "Maharashtra",
    "Product_Category": "Pipes",
    "Prouct_sub_Category": "CPVC Pipe",
    "Product_Id": "PP002",
    "Product_Name": "AquaLine CPVC 3/4 inch",
    "Product_Description": "Heat resistant CPVC pipe for hot water systems",
    "Unit_Price": 15.80,
    "Current_Stock": 7200,
    "Lead_time_days": 5,
    "Total_orders": 1280,
    "Total_units_supplied": 16500,
    "Return_Units": 195,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "PIP003",
    "Manufacturer_name": "SteelCore Tubes",
    "Manufacturer_address": "88 Metal Park",
    "Manufacturer_State": "Tamil Nadu",
    "Product_Category": "Pipes",
    "Prouct_sub_Category": "GI Pipe",
    "Product_Id": "PP003",
    "Product_Name": "SteelCore GI 2 inch",
    "Product_Description": "Galvanized iron pipe for plumbing applications",
    "Unit_Price": 28.40,
    "Current_Stock": 4300,
    "Lead_time_days": 6,
    "Total_orders": 860,
    "Total_units_supplied": 10400,
    "Return_Units": 140,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.3
  },
  {
    "Manufacturer_id": "PIP004",
    "Manufacturer_name": "HydroFlex Systems",
    "Manufacturer_address": "19 Industrial Corridor",
    "Manufacturer_State": "Karnataka",
    "Product_Category": "Pipes",
    "Prouct_sub_Category": "HDPE Pipe",
    "Product_Id": "PP004",
    "Product_Name": "HydroFlex HDPE 4 inch",
    "Product_Description": "Durable HDPE pipe for irrigation systems",
    "Unit_Price": 45.00,
    "Current_Stock": 3800,
    "Lead_time_days": 7,
    "Total_orders": 720,
    "Total_units_supplied": 9800,
    "Return_Units": 110,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "PIP005",
    "Manufacturer_name": "PrimeFlow Manufacturing",
    "Manufacturer_address": "67 Engineering Park",
    "Manufacturer_State": "Punjab",
    "Product_Category": "Pipes",
    "Prouct_sub_Category": "PVC Pipe",
    "Product_Id": "PP005",
    "Product_Name": "PrimeFlow PVC 1.5 inch",
    "Product_Description": "Heavy duty PVC pipe for drainage",
    "Unit_Price": 18.75,
    "Current_Stock": 6100,
    "Lead_time_days": 5,
    "Total_orders": 990,
    "Total_units_supplied": 13200,
    "Return_Units": 165,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.4
  },

  {
    "Manufacturer_id": "PIP006",
    "Manufacturer_name": "UrbanPipe Co.",
    "Manufacturer_address": "22 Supply Chain Road",
    "Manufacturer_State": "Rajasthan",
    "Product_Category": "Pipes",
    "Prouct_sub_Category": "CPVC Pipe",
    "Product_Id": "PP006",
    "Product_Name": "UrbanPipe CPVC 1 inch",
    "Product_Description": "Corrosion resistant CPVC plumbing pipe",
    "Unit_Price": 16.20,
    "Current_Stock": 5400,
    "Lead_time_days": 4,
    "Total_orders": 1020,
    "Total_units_supplied": 14100,
    "Return_Units": 180,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.5
  },

  {
    "Manufacturer_id": "PIP007",
    "Manufacturer_name": "MegaSteel Pipes",
    "Manufacturer_address": "101 Steel Yard",
    "Manufacturer_State": "Haryana",
    "Product_Category": "Pipes",
    "Prouct_sub_Category": "Steel Pipe",
    "Product_Id": "PP007",
    "Product_Name": "MegaSteel MS 3 inch",
    "Product_Description": "Mild steel pipe for industrial usage",
    "Unit_Price": 55.60,
    "Current_Stock": 2900,
    "Lead_time_days": 8,
    "Total_orders": 610,
    "Total_units_supplied": 8400,
    "Return_Units": 120,
    "Response_Time_in_hrs": 10,
    "Ratings": 4.2
  },

  {
    "Manufacturer_id": "PIP008",
    "Manufacturer_name": "AquaPro Tubes",
    "Manufacturer_address": "33 Waterworks Lane",
    "Manufacturer_State": "Uttar Pradesh",
    "Product_Category": "Pipes",
    "Prouct_sub_Category": "HDPE Pipe",
    "Product_Id": "PP008",
    "Product_Name": "AquaPro HDPE 6 inch",
    "Product_Description": "Flexible HDPE pipe for agricultural use",
    "Unit_Price": 62.00,
    "Current_Stock": 2100,
    "Lead_time_days": 7,
    "Total_orders": 480,
    "Total_units_supplied": 6200,
    "Return_Units": 95,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "PIP009",
    "Manufacturer_name": "BlueWave Pipelines",
    "Manufacturer_address": "54 Industrial Harbor",
    "Manufacturer_State": "Andhra Pradesh",
    "Product_Category": "Pipes",
    "Prouct_sub_Category": "PVC Pipe",
    "Product_Id": "PP009",
    "Product_Name": "BlueWave PVC 2 inch",
    "Product_Description": "Durable PVC pipe for residential plumbing",
    "Unit_Price": 21.30,
    "Current_Stock": 5700,
    "Lead_time_days": 4,
    "Total_orders": 1120,
    "Total_units_supplied": 15000,
    "Return_Units": 205,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "PIP010",
    "Manufacturer_name": "TitanFlow Engineering",
    "Manufacturer_address": "9 Industrial Ring Road",
    "Manufacturer_State": "Chhattisgarh",
    "Product_Category": "Pipes",
    "Prouct_sub_Category": "Steel Pipe",
    "Product_Id": "PP010",
    "Product_Name": "TitanFlow Steel 4 inch",
    "Product_Description": "Heavy duty steel pipe for construction projects",
    "Unit_Price": 78.90,
    "Current_Stock": 2400,
    "Lead_time_days": 9,
    "Total_orders": 530,
    "Total_units_supplied": 7300,
    "Return_Units": 98,
    "Response_Time_in_hrs": 11,
    "Ratings": 4.3
  },
  {
    "Manufacturer_id": "PIP011",
    "Manufacturer_name": "CrystalFlow Plastics",
    "Manufacturer_address": "77 Polymer Street",
    "Manufacturer_State": "Kerala",
    "Product_Category": "Pipes",
    "Prouct_sub_Category": "CPVC Pipe",
    "Product_Id": "PP011",
    "Product_Name": "CrystalFlow CPVC 1.25 inch",
    "Product_Description": "Premium CPVC pipe for hot and cold water supply",
    "Unit_Price": 19.40,
    "Current_Stock": 6200,
    "Lead_time_days": 5,
    "Total_orders": 980,
    "Total_units_supplied": 13600,
    "Return_Units": 170,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "PIP012",
    "Manufacturer_name": "AquaStrong Industries",
    "Manufacturer_address": "31 Water Channel Road",
    "Manufacturer_State": "Bihar",
    "Product_Category": "Pipes",
    "Prouct_sub_Category": "HDPE Pipe",
    "Product_Id": "PP012",
    "Product_Name": "AquaStrong HDPE 3 inch",
    "Product_Description": "Impact resistant HDPE pipe for irrigation",
    "Unit_Price": 48.75,
    "Current_Stock": 3600,
    "Lead_time_days": 6,
    "Total_orders": 770,
    "Total_units_supplied": 9900,
    "Return_Units": 145,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "PIP013",
    "Manufacturer_name": "RapidFlow Tubes",
    "Manufacturer_address": "88 Utility Park",
    "Manufacturer_State": "Jharkhand",
    "Product_Category": "Pipes",
    "Prouct_sub_Category": "GI Pipe",
    "Product_Id": "PP013",
    "Product_Name": "RapidFlow GI 1.5 inch",
    "Product_Description": "Galvanized iron pipe for water pipelines",
    "Unit_Price": 32.10,
    "Current_Stock": 4100,
    "Lead_time_days": 5,
    "Total_orders": 890,
    "Total_units_supplied": 11800,
    "Return_Units": 160,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "PIP014",
    "Manufacturer_name": "UltraPipe Manufacturing",
    "Manufacturer_address": "15 Engineering Estate",
    "Manufacturer_State": "West Bengal",
    "Product_Category": "Pipes",
    "Prouct_sub_Category": "PVC Pipe",
    "Product_Id": "PP014",
    "Product_Name": "UltraPipe PVC 3 inch",
    "Product_Description": "Thick wall PVC pipe for drainage systems",
    "Unit_Price": 26.50,
    "Current_Stock": 4800,
    "Lead_time_days": 4,
    "Total_orders": 1050,
    "Total_units_supplied": 14200,
    "Return_Units": 185,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "PIP015",
    "Manufacturer_name": "HydroLink Solutions",
    "Manufacturer_address": "29 Industrial Dock",
    "Manufacturer_State": "Uttarakhand",
    "Product_Category": "Pipes",
    "Prouct_sub_Category": "Steel Pipe",
    "Product_Id": "PP015",
    "Product_Name": "HydroLink Steel 5 inch",
    "Product_Description": "Industrial grade steel pipe for heavy duty use",
    "Unit_Price": 92.00,
    "Current_Stock": 1900,
    "Lead_time_days": 10,
    "Total_orders": 420,
    "Total_units_supplied": 6100,
    "Return_Units": 88,
    "Response_Time_in_hrs": 12,
    "Ratings": 4.2
  },
  {
    "Manufacturer_id": "S001",
    "Manufacturer_name": "PureGlow Industries",
    "Manufacturer_address": "12 Hygiene Park",
    "Manufacturer_State": "Gujarat",
    "Product_Category": "Soap",
    "Prouct_sub_Category": "Bathing Soap",
    "Product_Id": "SP001",
    "Product_Name": "PureGlow Fresh Aloe Bar",
    "Product_Description": "Moisturizing aloe vera bathing soap",
    "Unit_Price": 0.85,
    "Current_Stock": 15000,
    "Lead_time_days": 3,
    "Total_orders": 2400,
    "Total_units_supplied": 32000,
    "Return_Units": 420,
    "Response_Time_in_hrs": 5,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "S002",
    "Manufacturer_name": "HerbalCare Products",
    "Manufacturer_address": "45 Natural Street",
    "Manufacturer_State": "Kerala",
    "Product_Category": "Soap",
    "Prouct_sub_Category": "Herbal Soap",
    "Product_Id": "SP002",
    "Product_Name": "HerbalCare Neem Protect",
    "Product_Description": "Antibacterial neem herbal soap",
    "Unit_Price": 1.10,
    "Current_Stock": 12000,
    "Lead_time_days": 4,
    "Total_orders": 2100,
    "Total_units_supplied": 27500,
    "Return_Units": 360,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "S003",
    "Manufacturer_name": "FreshAura FMCG",
    "Manufacturer_address": "88 Clean Avenue",
    "Manufacturer_State": "Maharashtra",
    "Product_Category": "Soap",
    "Prouct_sub_Category": "Liquid Soap",
    "Product_Id": "SP003",
    "Product_Name": "FreshAura HandWash Lemon",
    "Product_Description": "Liquid handwash with lemon fragrance",
    "Unit_Price": 2.40,
    "Current_Stock": 8500,
    "Lead_time_days": 4,
    "Total_orders": 1850,
    "Total_units_supplied": 22000,
    "Return_Units": 280,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "S004",
    "Manufacturer_name": "NatureBlend Soaps",
    "Manufacturer_address": "19 Organic Park",
    "Manufacturer_State": "Tamil Nadu",
    "Product_Category": "Soap",
    "Prouct_sub_Category": "Organic Soap",
    "Product_Id": "SP004",
    "Product_Name": "NatureBlend Lavender Bliss",
    "Product_Description": "Organic lavender soap for sensitive skin",
    "Unit_Price": 1.95,
    "Current_Stock": 6400,
    "Lead_time_days": 5,
    "Total_orders": 1320,
    "Total_units_supplied": 16800,
    "Return_Units": 190,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "S005",
    "Manufacturer_name": "CleanWave Consumer",
    "Manufacturer_address": "67 Hygiene Estate",
    "Manufacturer_State": "Delhi",
    "Product_Category": "Soap",
    "Prouct_sub_Category": "Antibacterial Soap",
    "Product_Id": "SP005",
    "Product_Name": "CleanWave Shield Plus",
    "Product_Description": "Antibacterial soap with germ protection",
    "Unit_Price": 1.25,
    "Current_Stock": 11200,
    "Lead_time_days": 3,
    "Total_orders": 1980,
    "Total_units_supplied": 25400,
    "Return_Units": 330,
    "Response_Time_in_hrs": 5,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "S006",
    "Manufacturer_name": "AromaFresh Ltd",
    "Manufacturer_address": "22 Aroma Street",
    "Manufacturer_State": "Punjab",
    "Product_Category": "Soap",
    "Prouct_sub_Category": "Bathing Soap",
    "Product_Id": "SP006",
    "Product_Name": "AromaFresh Rose Glow",
    "Product_Description": "Rose fragrance bathing soap",
    "Unit_Price": 0.95,
    "Current_Stock": 14500,
    "Lead_time_days": 3,
    "Total_orders": 2300,
    "Total_units_supplied": 30000,
    "Return_Units": 410,
    "Response_Time_in_hrs": 5,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "S007",
    "Manufacturer_name": "EcoPure Hygiene",
    "Manufacturer_address": "31 Eco Valley",
    "Manufacturer_State": "Karnataka",
    "Product_Category": "Soap",
    "Prouct_sub_Category": "Herbal Soap",
    "Product_Id": "SP007",
    "Product_Name": "EcoPure Turmeric Care",
    "Product_Description": "Herbal turmeric soap for glowing skin",
    "Unit_Price": 1.30,
    "Current_Stock": 9800,
    "Lead_time_days": 4,
    "Total_orders": 1750,
    "Total_units_supplied": 21400,
    "Return_Units": 290,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "S008",
    "Manufacturer_name": "FreshNest FMCG",
    "Manufacturer_address": "54 Clean City Road",
    "Manufacturer_State": "Rajasthan",
    "Product_Category": "Soap",
    "Prouct_sub_Category": "Liquid Soap",
    "Product_Id": "SP008",
    "Product_Name": "FreshNest Apple Handwash",
    "Product_Description": "Refreshing apple scented liquid soap",
    "Unit_Price": 2.10,
    "Current_Stock": 7200,
    "Lead_time_days": 4,
    "Total_orders": 1620,
    "Total_units_supplied": 19800,
    "Return_Units": 250,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.3
  },
  {
    "Manufacturer_id": "S009",
    "Manufacturer_name": "GlowLife Products",
    "Manufacturer_address": "78 Wellness Street",
    "Manufacturer_State": "Uttar Pradesh",
    "Product_Category": "Soap",
    "Prouct_sub_Category": "Moisturizing Soap",
    "Product_Id": "SP009",
    "Product_Name": "GlowLife Cocoa Butter Bar",
    "Product_Description": "Deep moisturizing soap with cocoa butter",
    "Unit_Price": 1.40,
    "Current_Stock": 8900,
    "Lead_time_days": 4,
    "Total_orders": 1680,
    "Total_units_supplied": 20500,
    "Return_Units": 275,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "S010",
    "Manufacturer_name": "PureSkin Naturals",
    "Manufacturer_address": "16 Herbal Avenue",
    "Manufacturer_State": "Himachal Pradesh",
    "Product_Category": "Soap",
    "Prouct_sub_Category": "Organic Soap",
    "Product_Id": "SP010",
    "Product_Name": "PureSkin Charcoal Detox",
    "Product_Description": "Activated charcoal soap for deep cleansing",
    "Unit_Price": 2.00,
    "Current_Stock": 7600,
    "Lead_time_days": 5,
    "Total_orders": 1490,
    "Total_units_supplied": 18300,
    "Return_Units": 210,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "S011",
    "Manufacturer_name": "CarePlus FMCG",
    "Manufacturer_address": "90 Hygiene Park",
    "Manufacturer_State": "Telangana",
    "Product_Category": "Soap",
    "Prouct_sub_Category": "Antibacterial Soap",
    "Product_Id": "SP011",
    "Product_Name": "CarePlus Germ Defense",
    "Product_Description": "Advanced antibacterial soap with 99.9% germ protection",
    "Unit_Price": 1.35,
    "Current_Stock": 13400,
    "Lead_time_days": 3,
    "Total_orders": 2250,
    "Total_units_supplied": 29800,
    "Return_Units": 395,
    "Response_Time_in_hrs": 5,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "S012",
    "Manufacturer_name": "GreenLeaf Organics",
    "Manufacturer_address": "25 Eco Valley",
    "Manufacturer_State": "Goa",
    "Product_Category": "Soap",
    "Prouct_sub_Category": "Herbal Soap",
    "Product_Id": "SP012",
    "Product_Name": "GreenLeaf Mint Fresh",
    "Product_Description": "Mint infused herbal soap for refreshing feel",
    "Unit_Price": 1.15,
    "Current_Stock": 9100,
    "Lead_time_days": 4,
    "Total_orders": 1720,
    "Total_units_supplied": 21500,
    "Return_Units": 285,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "S013",
    "Manufacturer_name": "AquaCare Hygiene",
    "Manufacturer_address": "61 Clean Park",
    "Manufacturer_State": "Odisha",
    "Product_Category": "Soap",
    "Prouct_sub_Category": "Liquid Soap",
    "Product_Id": "SP013",
    "Product_Name": "AquaCare Ocean Blue",
    "Product_Description": "Ocean fragrance liquid hand soap",
    "Unit_Price": 2.25,
    "Current_Stock": 6800,
    "Lead_time_days": 4,
    "Total_orders": 1580,
    "Total_units_supplied": 19400,
    "Return_Units": 245,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.3
  },
  {
    "Manufacturer_id": "S014",
    "Manufacturer_name": "NatureTouch Soaps",
    "Manufacturer_address": "42 Herbal Market",
    "Manufacturer_State": "Bihar",
    "Product_Category": "Soap",
    "Prouct_sub_Category": "Moisturizing Soap",
    "Product_Id": "SP014",
    "Product_Name": "NatureTouch Almond Cream",
    "Product_Description": "Almond enriched moisturizing bathing soap",
    "Unit_Price": 1.55,
    "Current_Stock": 8200,
    "Lead_time_days": 4,
    "Total_orders": 1660,
    "Total_units_supplied": 20800,
    "Return_Units": 270,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "S015",
    "Manufacturer_name": "FreshBloom FMCG",
    "Manufacturer_address": "73 Blossom Street",
    "Manufacturer_State": "West Bengal",
    "Product_Category": "Soap",
    "Prouct_sub_Category": "Bathing Soap",
    "Product_Id": "SP015",
    "Product_Name": "FreshBloom Jasmine Glow",
    "Product_Description": "Jasmine scented bathing soap for soft skin",
    "Unit_Price": 0.90,
    "Current_Stock": 14800,
    "Lead_time_days": 3,
    "Total_orders": 2380,
    "Total_units_supplied": 31000,
    "Return_Units": 420,
    "Response_Time_in_hrs": 5,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "FR001",
    "Manufacturer_name": "CoolTech Appliances",
    "Manufacturer_address": "12 Cooling Estate",
    "Manufacturer_State": "Maharashtra",
    "Product_Category": "Fridges",
    "Prouct_sub_Category": "Single Door",
    "Product_Id": "FG001",
    "Product_Name": "CoolTech Chill 190L",
    "Product_Description": "190L single door refrigerator with energy saving mode",
    "Unit_Price": 210.00,
    "Current_Stock": 420,
    "Lead_time_days": 6,
    "Total_orders": 380,
    "Total_units_supplied": 3200,
    "Return_Units": 55,
    "Response_Time_in_hrs": 10,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "FR002",
    "Manufacturer_name": "FrostLine Industries",
    "Manufacturer_address": "45 Appliance Park",
    "Manufacturer_State": "Gujarat",
    "Product_Category": "Fridges",
    "Prouct_sub_Category": "Double Door",
    "Product_Id": "FG002",
    "Product_Name": "FrostLine Fresh 260L",
    "Product_Description": "260L double door fridge with frost free cooling",
    "Unit_Price": 340.00,
    "Current_Stock": 310,
    "Lead_time_days": 7,
    "Total_orders": 290,
    "Total_units_supplied": 2500,
    "Return_Units": 40,
    "Response_Time_in_hrs": 11,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "FR003",
    "Manufacturer_name": "IceWave HomeTech",
    "Manufacturer_address": "88 Chill Street",
    "Manufacturer_State": "Tamil Nadu",
    "Product_Category": "Fridges",
    "Prouct_sub_Category": "Side by Side",
    "Product_Id": "FG003",
    "Product_Name": "IceWave Premium 500L",
    "Product_Description": "500L side-by-side refrigerator with inverter compressor",
    "Unit_Price": 820.00,
    "Current_Stock": 120,
    "Lead_time_days": 9,
    "Total_orders": 160,
    "Total_units_supplied": 1300,
    "Return_Units": 22,
    "Response_Time_in_hrs": 14,
    "Ratings": 4.8
  },
  {
    "Manufacturer_id": "FR004",
    "Manufacturer_name": "ArcticHome Appliances",
    "Manufacturer_address": "19 Freeze Avenue",
    "Manufacturer_State": "Delhi",
    "Product_Category": "Fridges",
    "Prouct_sub_Category": "Top Freezer",
    "Product_Id": "FG004",
    "Product_Name": "ArcticHome FreezeMax 240L",
    "Product_Description": "Top freezer refrigerator with rapid cooling",
    "Unit_Price": 300.00,
    "Current_Stock": 270,
    "Lead_time_days": 6,
    "Total_orders": 320,
    "Total_units_supplied": 2800,
    "Return_Units": 48,
    "Response_Time_in_hrs": 10,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "FR005",
    "Manufacturer_name": "ChillPro Electronics",
    "Manufacturer_address": "67 Appliance Hub",
    "Manufacturer_State": "Karnataka",
    "Product_Category": "Fridges",
    "Prouct_sub_Category": "Bottom Freezer",
    "Product_Id": "FG005",
    "Product_Name": "ChillPro SmartCool 310L",
    "Product_Description": "Bottom freezer fridge with digital display",
    "Unit_Price": 450.00,
    "Current_Stock": 210,
    "Lead_time_days": 8,
    "Total_orders": 240,
    "Total_units_supplied": 1900,
    "Return_Units": 35,
    "Response_Time_in_hrs": 12,
    "Ratings": 4.7
  },

  {
    "Manufacturer_id": "FR006",
    "Manufacturer_name": "FreshNest Appliances",
    "Manufacturer_address": "22 Cooling Zone",
    "Manufacturer_State": "Punjab",
    "Product_Category": "Fridges",
    "Prouct_sub_Category": "Single Door",
    "Product_Id": "FG006",
    "Product_Name": "FreshNest Eco 180L",
    "Product_Description": "Energy efficient single door fridge",
    "Unit_Price": 195.00,
    "Current_Stock": 460,
    "Lead_time_days": 5,
    "Total_orders": 420,
    "Total_units_supplied": 3600,
    "Return_Units": 60,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.3
  },

  {
    "Manufacturer_id": "FR007",
    "Manufacturer_name": "PolarTech Systems",
    "Manufacturer_address": "31 Ice Park",
    "Manufacturer_State": "Rajasthan",
    "Product_Category": "Fridges",
    "Prouct_sub_Category": "Double Door",
    "Product_Id": "FG007",
    "Product_Name": "PolarTech FrostFree 275L",
    "Product_Description": "Frost free double door refrigerator",
    "Unit_Price": 365.00,
    "Current_Stock": 280,
    "Lead_time_days": 7,
    "Total_orders": 310,
    "Total_units_supplied": 2600,
    "Return_Units": 44,
    "Response_Time_in_hrs": 11,
    "Ratings": 4.6
  },

  {
    "Manufacturer_id": "FR008",
    "Manufacturer_name": "CoolSphere Ltd",
    "Manufacturer_address": "54 Freeze Street",
    "Manufacturer_State": "Uttar Pradesh",
    "Product_Category": "Fridges",
    "Prouct_sub_Category": "Side by Side",
    "Product_Id": "FG008",
    "Product_Name": "CoolSphere Elite 520L",
    "Product_Description": "Large capacity side-by-side refrigerator",
    "Unit_Price": 890.00,
    "Current_Stock": 110,
    "Lead_time_days": 9,
    "Total_orders": 150,
    "Total_units_supplied": 1200,
    "Return_Units": 20,
    "Response_Time_in_hrs": 14,
    "Ratings": 4.9
  },
  {
    "Manufacturer_id": "FR009",
    "Manufacturer_name": "GlacierHome Appliances",
    "Manufacturer_address": "72 Frost Industrial Area",
    "Manufacturer_State": "Haryana",
    "Product_Category": "Fridges",
    "Prouct_sub_Category": "Single Door",
    "Product_Id": "FG009",
    "Product_Name": "GlacierHome CoolLite 200L",
    "Product_Description": "Compact single door refrigerator with fast cooling",
    "Unit_Price": 220.00,
    "Current_Stock": 390,
    "Lead_time_days": 6,
    "Total_orders": 350,
    "Total_units_supplied": 3000,
    "Return_Units": 52,
    "Response_Time_in_hrs": 10,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "FR010",
    "Manufacturer_name": "FrostNova Electronics",
    "Manufacturer_address": "11 IceTech Park",
    "Manufacturer_State": "West Bengal",
    "Product_Category": "Fridges",
    "Prouct_sub_Category": "Double Door",
    "Product_Id": "FG010",
    "Product_Name": "FrostNova FreshGuard 280L",
    "Product_Description": "Double door refrigerator with smart temperature control",
    "Unit_Price": 370.00,
    "Current_Stock": 260,
    "Lead_time_days": 7,
    "Total_orders": 295,
    "Total_units_supplied": 2450,
    "Return_Units": 39,
    "Response_Time_in_hrs": 11,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "FR011",
    "Manufacturer_name": "ArcticZone Pvt Ltd",
    "Manufacturer_address": "28 Chill Plaza",
    "Manufacturer_State": "Telangana",
    "Product_Category": "Fridges",
    "Prouct_sub_Category": "Bottom Freezer",
    "Product_Id": "FG011",
    "Product_Name": "ArcticZone SmartChill 330L",
    "Product_Description": "Bottom freezer fridge with digital inverter technology",
    "Unit_Price": 480.00,
    "Current_Stock": 190,
    "Lead_time_days": 8,
    "Total_orders": 210,
    "Total_units_supplied": 1700,
    "Return_Units": 30,
    "Response_Time_in_hrs": 12,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "FR012",
    "Manufacturer_name": "CoolVista Appliances",
    "Manufacturer_address": "44 Snow Street",
    "Manufacturer_State": "Kerala",
    "Product_Category": "Fridges",
    "Prouct_sub_Category": "Side by Side",
    "Product_Id": "FG012",
    "Product_Name": "CoolVista Grand 540L",
    "Product_Description": "Spacious side-by-side refrigerator with touch panel",
    "Unit_Price": 910.00,
    "Current_Stock": 105,
    "Lead_time_days": 9,
    "Total_orders": 140,
    "Total_units_supplied": 1150,
    "Return_Units": 18,
    "Response_Time_in_hrs": 15,
    "Ratings": 4.9
  },
  {
    "Manufacturer_id": "FR013",
    "Manufacturer_name": "IcePeak Technologies",
    "Manufacturer_address": "63 Freeze Line",
    "Manufacturer_State": "Odisha",
    "Product_Category": "Fridges",
    "Prouct_sub_Category": "Top Freezer",
    "Product_Id": "FG013",
    "Product_Name": "IcePeak RapidCool 250L",
    "Product_Description": "Top freezer refrigerator with humidity control",
    "Unit_Price": 315.00,
    "Current_Stock": 240,
    "Lead_time_days": 6,
    "Total_orders": 300,
    "Total_units_supplied": 2550,
    "Return_Units": 41,
    "Response_Time_in_hrs": 10,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "FR014",
    "Manufacturer_name": "SnowLine HomeTech",
    "Manufacturer_address": "18 Ice Avenue",
    "Manufacturer_State": "Bihar",
    "Product_Category": "Fridges",
    "Prouct_sub_Category": "Single Door",
    "Product_Id": "FG014",
    "Product_Name": "SnowLine Fresh 210L",
    "Product_Description": "Energy star rated single door fridge",
    "Unit_Price": 230.00,
    "Current_Stock": 360,
    "Lead_time_days": 5,
    "Total_orders": 340,
    "Total_units_supplied": 2950,
    "Return_Units": 50,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "FR015",
    "Manufacturer_name": "ChillMatrix Appliances",
    "Manufacturer_address": "91 Cooling Dock",
    "Manufacturer_State": "Jharkhand",
    "Product_Category": "Fridges",
    "Prouct_sub_Category": "Double Door",
    "Product_Id": "FG015",
    "Product_Name": "ChillMatrix EcoCool 290L",
    "Product_Description": "Double door refrigerator with eco inverter compressor",
    "Unit_Price": 385.00,
    "Current_Stock": 230,
    "Lead_time_days": 7,
    "Total_orders": 285,
    "Total_units_supplied": 2350,
    "Return_Units": 36,
    "Response_Time_in_hrs": 11,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "TV001",
    "Manufacturer_name": "VisionTech Electronics",
    "Manufacturer_address": "12 Media Park",
    "Manufacturer_State": "Maharashtra",
    "Product_Category": "TV",
    "Prouct_sub_Category": "LED TV",
    "Product_Id": "TVP001",
    "Product_Name": "VisionTech LED 32\" HD",
    "Product_Description": "32 inch HD Ready LED television with HDMI support",
    "Unit_Price": 180.00,
    "Current_Stock": 520,
    "Lead_time_days": 5,
    "Total_orders": 680,
    "Total_units_supplied": 5600,
    "Return_Units": 95,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "TV002",
    "Manufacturer_name": "UltraView Systems",
    "Manufacturer_address": "45 Display Avenue",
    "Manufacturer_State": "Tamil Nadu",
    "Product_Category": "TV",
    "Prouct_sub_Category": "Smart TV",
    "Product_Id": "TVP002",
    "Product_Name": "UltraView Smart 43\" FHD",
    "Product_Description": "43 inch Full HD smart TV with built-in apps",
    "Unit_Price": 320.00,
    "Current_Stock": 410,
    "Lead_time_days": 6,
    "Total_orders": 540,
    "Total_units_supplied": 4700,
    "Return_Units": 78,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "TV003",
    "Manufacturer_name": "PixelWave Technologies",
    "Manufacturer_address": "88 Screen Hub",
    "Manufacturer_State": "Karnataka",
    "Product_Category": "TV",
    "Prouct_sub_Category": "4K UHD TV",
    "Product_Id": "TVP003",
    "Product_Name": "PixelWave Ultra 55\" 4K",
    "Product_Description": "55 inch 4K UHD television with HDR support",
    "Unit_Price": 590.00,
    "Current_Stock": 260,
    "Lead_time_days": 7,
    "Total_orders": 390,
    "Total_units_supplied": 3200,
    "Return_Units": 60,
    "Response_Time_in_hrs": 10,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "TV004",
    "Manufacturer_name": "CrystalVision Pvt Ltd",
    "Manufacturer_address": "19 Display Street",
    "Manufacturer_State": "Delhi",
    "Product_Category": "TV",
    "Prouct_sub_Category": "OLED TV",
    "Product_Id": "TVP004",
    "Product_Name": "CrystalVision OLED 65\"",
    "Product_Description": "65 inch OLED smart TV with deep contrast display",
    "Unit_Price": 1200.00,
    "Current_Stock": 140,
    "Lead_time_days": 9,
    "Total_orders": 180,
    "Total_units_supplied": 1500,
    "Return_Units": 22,
    "Response_Time_in_hrs": 12,
    "Ratings": 4.9
  },
  {
    "Manufacturer_id": "TV005",
    "Manufacturer_name": "HomeScreen Appliances",
    "Manufacturer_address": "67 Tech Estate",
    "Manufacturer_State": "Gujarat",
    "Product_Category": "TV",
    "Prouct_sub_Category": "LED TV",
    "Product_Id": "TVP005",
    "Product_Name": "HomeScreen LED 40\"",
    "Product_Description": "40 inch LED TV with surround sound support",
    "Unit_Price": 250.00,
    "Current_Stock": 370,
    "Lead_time_days": 6,
    "Total_orders": 520,
    "Total_units_supplied": 4300,
    "Return_Units": 70,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "TV006",
    "Manufacturer_name": "NovaDisplay Corp",
    "Manufacturer_address": "22 Vision Park",
    "Manufacturer_State": "Punjab",
    "Product_Category": "TV",
    "Prouct_sub_Category": "Smart TV",
    "Product_Id": "TVP006",
    "Product_Name": "NovaDisplay Smart 50\"",
    "Product_Description": "50 inch smart TV with voice assistant",
    "Unit_Price": 420.00,
    "Current_Stock": 310,
    "Lead_time_days": 6,
    "Total_orders": 460,
    "Total_units_supplied": 3900,
    "Return_Units": 65,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "TV007",
    "Manufacturer_name": "BrightView Electronics",
    "Manufacturer_address": "31 Media Street",
    "Manufacturer_State": "Rajasthan",
    "Product_Category": "TV",
    "Prouct_sub_Category": "4K UHD TV",
    "Product_Id": "TVP007",
    "Product_Name": "BrightView UltraHD 60\"",
    "Product_Description": "60 inch 4K Ultra HD television",
    "Unit_Price": 670.00,
    "Current_Stock": 220,
    "Lead_time_days": 7,
    "Total_orders": 340,
    "Total_units_supplied": 2800,
    "Return_Units": 50,
    "Response_Time_in_hrs": 10,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "TV008",
    "Manufacturer_name": "MegaPixel HomeTech",
    "Manufacturer_address": "54 Cinema Avenue",
    "Manufacturer_State": "Uttar Pradesh",
    "Product_Category": "TV",
    "Prouct_sub_Category": "QLED TV",
    "Product_Id": "TVP008",
    "Product_Name": "MegaPixel QLED 75\"",
    "Product_Description": "75 inch QLED TV with cinematic picture quality",
    "Unit_Price": 1500.00,
    "Current_Stock": 90,
    "Lead_time_days": 10,
    "Total_orders": 150,
    "Total_units_supplied": 1100,
    "Return_Units": 18,
    "Response_Time_in_hrs": 14,
    "Ratings": 4.9
  },
  {
    "Manufacturer_id": "TV002",
    "Manufacturer_name": "UltraView Systems",
    "Manufacturer_address": "45 Display Avenue",
    "Manufacturer_State": "Tamil Nadu",
    "Product_Category": "TV",
    "Prouct_sub_Category": "Smart TV",
    "Product_Id": "TVP002",
    "Product_Name": "UltraView Smart 43\" FHD",
    "Product_Description": "43 inch Full HD smart TV with built-in apps",
    "Unit_Price": 320.00,
    "Current_Stock": 410,
    "Lead_time_days": 6,
    "Total_orders": 540,
    "Total_units_supplied": 4700,
    "Return_Units": 78,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "TV003",
    "Manufacturer_name": "PixelWave Technologies",
    "Manufacturer_address": "88 Screen Hub",
    "Manufacturer_State": "Karnataka",
    "Product_Category": "TV",
    "Prouct_sub_Category": "4K UHD TV",
    "Product_Id": "TVP003",
    "Product_Name": "PixelWave Ultra 55\" 4K",
    "Product_Description": "55 inch 4K UHD television with HDR support",
    "Unit_Price": 590.00,
    "Current_Stock": 260,
    "Lead_time_days": 7,
    "Total_orders": 390,
    "Total_units_supplied": 3200,
    "Return_Units": 60,
    "Response_Time_in_hrs": 10,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "TV004",
    "Manufacturer_name": "CrystalVision Pvt Ltd",
    "Manufacturer_address": "19 Display Street",
    "Manufacturer_State": "Delhi",
    "Product_Category": "TV",
    "Prouct_sub_Category": "OLED TV",
    "Product_Id": "TVP004",
    "Product_Name": "CrystalVision OLED 65\"",
    "Product_Description": "65 inch OLED smart TV with deep contrast display",
    "Unit_Price": 1200.00,
    "Current_Stock": 140,
    "Lead_time_days": 9,
    "Total_orders": 180,
    "Total_units_supplied": 1500,
    "Return_Units": 22,
    "Response_Time_in_hrs": 12,
    "Ratings": 4.9
  },
  {
    "Manufacturer_id": "TV005",
    "Manufacturer_name": "HomeScreen Appliances",
    "Manufacturer_address": "67 Tech Estate",
    "Manufacturer_State": "Gujarat",
    "Product_Category": "TV",
    "Prouct_sub_Category": "LED TV",
    "Product_Id": "TVP005",
    "Product_Name": "HomeScreen LED 40\"",
    "Product_Description": "40 inch LED TV with surround sound support",
    "Unit_Price": 250.00,
    "Current_Stock": 370,
    "Lead_time_days": 6,
    "Total_orders": 520,
    "Total_units_supplied": 4300,
    "Return_Units": 70,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "TV006",
    "Manufacturer_name": "NovaDisplay Corp",
    "Manufacturer_address": "22 Vision Park",
    "Manufacturer_State": "Punjab",
    "Product_Category": "TV",
    "Prouct_sub_Category": "Smart TV",
    "Product_Id": "TVP006",
    "Product_Name": "NovaDisplay Smart 50\"",
    "Product_Description": "50 inch smart TV with voice assistant",
    "Unit_Price": 420.00,
    "Current_Stock": 310,
    "Lead_time_days": 6,
    "Total_orders": 460,
    "Total_units_supplied": 3900,
    "Return_Units": 65,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "TV007",
    "Manufacturer_name": "BrightView Electronics",
    "Manufacturer_address": "31 Media Street",
    "Manufacturer_State": "Rajasthan",
    "Product_Category": "TV",
    "Prouct_sub_Category": "4K UHD TV",
    "Product_Id": "TVP007",
    "Product_Name": "BrightView UltraHD 60\"",
    "Product_Description": "60 inch 4K Ultra HD television",
    "Unit_Price": 670.00,
    "Current_Stock": 220,
    "Lead_time_days": 7,
    "Total_orders": 340,
    "Total_units_supplied": 2800,
    "Return_Units": 50,
    "Response_Time_in_hrs": 10,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "TV008",
    "Manufacturer_name": "MegaPixel HomeTech",
    "Manufacturer_address": "54 Cinema Avenue",
    "Manufacturer_State": "Uttar Pradesh",
    "Product_Category": "TV",
    "Prouct_sub_Category": "QLED TV",
    "Product_Id": "TVP008",
    "Product_Name": "MegaPixel QLED 75\"",
    "Product_Description": "75 inch QLED TV with cinematic picture quality",
    "Unit_Price": 1500.00,
    "Current_Stock": 90,
    "Lead_time_days": 10,
    "Total_orders": 150,
    "Total_units_supplied": 1100,
    "Return_Units": 18,
    "Response_Time_in_hrs": 14,
    "Ratings": 4.9
  },
  {
    "Manufacturer_id": "AC001",
    "Manufacturer_name": "CoolBreeze Appliances",
    "Manufacturer_address": "12 Climate Park",
    "Manufacturer_State": "Maharashtra",
    "Product_Category": "AC",
    "Prouct_sub_Category": "Split AC",
    "Product_Id": "ACP001",
    "Product_Name": "CoolBreeze Split 1 Ton",
    "Product_Description": "1 Ton split AC with inverter technology",
    "Unit_Price": 420.00,
    "Current_Stock": 320,
    "Lead_time_days": 6,
    "Total_orders": 540,
    "Total_units_supplied": 4200,
    "Return_Units": 65,
    "Response_Time_in_hrs": 10,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "AC002",
    "Manufacturer_name": "FrostAir Systems",
    "Manufacturer_address": "45 Cooling Avenue",
    "Manufacturer_State": "Gujarat",
    "Product_Category": "AC",
    "Prouct_sub_Category": "Window AC",
    "Product_Id": "ACP002",
    "Product_Name": "FrostAir Window 1.5 Ton",
    "Product_Description": "Energy efficient 1.5 Ton window AC",
    "Unit_Price": 390.00,
    "Current_Stock": 280,
    "Lead_time_days": 5,
    "Total_orders": 480,
    "Total_units_supplied": 3800,
    "Return_Units": 58,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "AC003",
    "Manufacturer_name": "PolarCool Pvt Ltd",
    "Manufacturer_address": "88 Airflow Street",
    "Manufacturer_State": "Tamil Nadu",
    "Product_Category": "AC",
    "Prouct_sub_Category": "Split AC",
    "Product_Id": "ACP003",
    "Product_Name": "PolarCool Smart 1.5 Ton",
    "Product_Description": "Smart split AC with WiFi connectivity",
    "Unit_Price": 510.00,
    "Current_Stock": 210,
    "Lead_time_days": 7,
    "Total_orders": 360,
    "Total_units_supplied": 2900,
    "Return_Units": 42,
    "Response_Time_in_hrs": 11,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "AC004",
    "Manufacturer_name": "ArcticWave Technologies",
    "Manufacturer_address": "19 Climate Zone",
    "Manufacturer_State": "Delhi",
    "Product_Category": "AC",
    "Prouct_sub_Category": "Cassette AC",
    "Product_Id": "ACP004",
    "Product_Name": "ArcticWave Cassette 2 Ton",
    "Product_Description": "2 Ton ceiling cassette AC for commercial use",
    "Unit_Price": 980.00,
    "Current_Stock": 90,
    "Lead_time_days": 9,
    "Total_orders": 140,
    "Total_units_supplied": 1100,
    "Return_Units": 18,
    "Response_Time_in_hrs": 14,
    "Ratings": 4.8
  },
  {
    "Manufacturer_id": "AC005",
    "Manufacturer_name": "EcoChill Appliances",
    "Manufacturer_address": "67 Cooling Estate",
    "Manufacturer_State": "Karnataka",
    "Product_Category": "AC",
    "Prouct_sub_Category": "Portable AC",
    "Product_Id": "ACP005",
    "Product_Name": "EcoChill Portable 1 Ton",
    "Product_Description": "Compact portable AC for small rooms",
    "Unit_Price": 350.00,
    "Current_Stock": 240,
    "Lead_time_days": 6,
    "Total_orders": 410,
    "Total_units_supplied": 3200,
    "Return_Units": 50,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.4
  },

  {
    "Manufacturer_id": "AC006",
    "Manufacturer_name": "SkyCool Industries",
    "Manufacturer_address": "22 Breeze Park",
    "Manufacturer_State": "Punjab",
    "Product_Category": "AC",
    "Prouct_sub_Category": "Split AC",
    "Product_Id": "ACP006",
    "Product_Name": "SkyCool Turbo 2 Ton",
    "Product_Description": "High performance 2 Ton split AC",
    "Unit_Price": 650.00,
    "Current_Stock": 170,
    "Lead_time_days": 8,
    "Total_orders": 300,
    "Total_units_supplied": 2400,
    "Return_Units": 36,
    "Response_Time_in_hrs": 12,
    "Ratings": 4.6
  },

  {
    "Manufacturer_id": "AC007",
    "Manufacturer_name": "CoolNest HomeTech",
    "Manufacturer_address": "31 Air Street",
    "Manufacturer_State": "Rajasthan",
    "Product_Category": "AC",
    "Prouct_sub_Category": "Window AC",
    "Product_Id": "ACP007",
    "Product_Name": "CoolNest Classic 1 Ton",
    "Product_Description": "Affordable 1 Ton window air conditioner",
    "Unit_Price": 360.00,
    "Current_Stock": 260,
    "Lead_time_days": 5,
    "Total_orders": 450,
    "Total_units_supplied": 3500,
    "Return_Units": 55,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.3
  },

  {
    "Manufacturer_id": "AC008",
    "Manufacturer_name": "ChillMax Electronics",
    "Manufacturer_address": "54 Cool Avenue",
    "Manufacturer_State": "Uttar Pradesh",
    "Product_Category": "AC",
    "Prouct_sub_Category": "Split AC",
    "Product_Id": "ACP008",
    "Product_Name": "ChillMax Inverter 1.5 Ton",
    "Product_Description": "Energy saving inverter split AC",
    "Unit_Price": 540.00,
    "Current_Stock": 200,
    "Lead_time_days": 7,
    "Total_orders": 370,
    "Total_units_supplied": 2950,
    "Return_Units": 40,
    "Response_Time_in_hrs": 10,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "AC009",
    "Manufacturer_name": "AirNova Cooling Systems",
    "Manufacturer_address": "72 Breeze Industrial Area",
    "Manufacturer_State": "Haryana",
    "Product_Category": "AC",
    "Prouct_sub_Category": "Split AC",
    "Product_Id": "ACP009",
    "Product_Name": "AirNova Prime 1 Ton",
    "Product_Description": "Compact inverter split AC with turbo cooling",
    "Unit_Price": 430.00,
    "Current_Stock": 290,
    "Lead_time_days": 6,
    "Total_orders": 500,
    "Total_units_supplied": 4100,
    "Return_Units": 60,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "AC010",
    "Manufacturer_name": "BreezeMaster Appliances",
    "Manufacturer_address": "18 Climate Road",
    "Manufacturer_State": "West Bengal",
    "Product_Category": "AC",
    "Prouct_sub_Category": "Window AC",
    "Product_Id": "ACP010",
    "Product_Name": "BreezeMaster Cool 1.5 Ton",
    "Product_Description": "High airflow window AC for medium rooms",
    "Unit_Price": 395.00,
    "Current_Stock": 250,
    "Lead_time_days": 5,
    "Total_orders": 460,
    "Total_units_supplied": 3650,
    "Return_Units": 52,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "AC011",
    "Manufacturer_name": "ClimatePro Pvt Ltd",
    "Manufacturer_address": "90 Cooling Hub",
    "Manufacturer_State": "Telangana",
    "Product_Category": "AC",
    "Prouct_sub_Category": "Split AC",
    "Product_Id": "ACP011",
    "Product_Name": "ClimatePro Smart 2 Ton",
    "Product_Description": "Smart 2 Ton AC with WiFi and voice control",
    "Unit_Price": 720.00,
    "Current_Stock": 160,
    "Lead_time_days": 8,
    "Total_orders": 280,
    "Total_units_supplied": 2200,
    "Return_Units": 30,
    "Response_Time_in_hrs": 12,
    "Ratings": 4.8
  },
  {
    "Manufacturer_id": "AC012",
    "Manufacturer_name": "FrostPeak Technologies",
    "Manufacturer_address": "44 Airflow Avenue",
    "Manufacturer_State": "Kerala",
    "Product_Category": "AC",
    "Prouct_sub_Category": "Portable AC",
    "Product_Id": "ACP012",
    "Product_Name": "FrostPeak MoveCool 1 Ton",
    "Product_Description": "Portable air conditioner with remote control",
    "Unit_Price": 360.00,
    "Current_Stock": 210,
    "Lead_time_days": 6,
    "Total_orders": 390,
    "Total_units_supplied": 3100,
    "Return_Units": 44,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.3
  },
  {
    "Manufacturer_id": "AC013",
    "Manufacturer_name": "ChillSphere Industries",
    "Manufacturer_address": "63 Cooling Plaza",
    "Manufacturer_State": "Odisha",
    "Product_Category": "AC",
    "Prouct_sub_Category": "Cassette AC",
    "Product_Id": "ACP013",
    "Product_Name": "ChillSphere Cassette 1.5 Ton",
    "Product_Description": "Ceiling mounted cassette AC for offices",
    "Unit_Price": 860.00,
    "Current_Stock": 120,
    "Lead_time_days": 9,
    "Total_orders": 190,
    "Total_units_supplied": 1450,
    "Return_Units": 20,
    "Response_Time_in_hrs": 13,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "AC014",
    "Manufacturer_name": "ArcticCool HomeTech",
    "Manufacturer_address": "28 Ice Street",
    "Manufacturer_State": "Bihar",
    "Product_Category": "AC",
    "Prouct_sub_Category": "Split AC",
    "Product_Id": "ACP014",
    "Product_Name": "ArcticCool Eco 1.5 Ton",
    "Product_Description": "Energy efficient split AC with eco mode",
    "Unit_Price": 505.00,
    "Current_Stock": 230,
    "Lead_time_days": 7,
    "Total_orders": 340,
    "Total_units_supplied": 2750,
    "Return_Units": 38,
    "Response_Time_in_hrs": 10,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "AC015",
    "Manufacturer_name": "CoolEdge Appliances",
    "Manufacturer_address": "91 Climate Lane",
    "Manufacturer_State": "Jharkhand",
    "Product_Category": "AC",
    "Prouct_sub_Category": "Window AC",
    "Product_Id": "ACP015",
    "Product_Name": "CoolEdge PowerCool 1 Ton",
    "Product_Description": "Powerful window AC with fast cooling",
    "Unit_Price": 370.00,
    "Current_Stock": 270,
    "Lead_time_days": 5,
    "Total_orders": 420,
    "Total_units_supplied": 3400,
    "Return_Units": 48,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "MB001",
    "Manufacturer_name": "NovaMobile Technologies",
    "Manufacturer_address": "12 SmartTech Park",
    "Manufacturer_State": "Karnataka",
    "Product_Category": "Mobiles",
    "Prouct_sub_Category": "Smartphone",
    "Product_Id": "MBP001",
    "Product_Name": "NovaMobile X1 Pro",
    "Product_Description": "6.5 inch smartphone with 8GB RAM and 128GB storage",
    "Unit_Price": 320.00,
    "Current_Stock": 850,
    "Lead_time_days": 4,
    "Total_orders": 1200,
    "Total_units_supplied": 9800,
    "Return_Units": 210,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "MB002",
    "Manufacturer_name": "SkyTech Communications",
    "Manufacturer_address": "45 Digital Avenue",
    "Manufacturer_State": "Maharashtra",
    "Product_Category": "Mobiles",
    "Prouct_sub_Category": "Smartphone",
    "Product_Id": "MBP002",
    "Product_Name": "SkyTech Ultra 5G",
    "Product_Description": "5G enabled smartphone with AMOLED display",
    "Unit_Price": 450.00,
    "Current_Stock": 620,
    "Lead_time_days": 5,
    "Total_orders": 980,
    "Total_units_supplied": 7600,
    "Return_Units": 160,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "MB003",
    "Manufacturer_name": "PixelCore Electronics",
    "Manufacturer_address": "88 Innovation Street",
    "Manufacturer_State": "Tamil Nadu",
    "Product_Category": "Mobiles",
    "Prouct_sub_Category": "Budget Smartphone",
    "Product_Id": "MBP003",
    "Product_Name": "PixelCore Lite A2",
    "Product_Description": "Affordable smartphone with 4GB RAM",
    "Unit_Price": 150.00,
    "Current_Stock": 1200,
    "Lead_time_days": 3,
    "Total_orders": 1600,
    "Total_units_supplied": 13400,
    "Return_Units": 320,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.3
  },
  {
    "Manufacturer_id": "MB004",
    "Manufacturer_name": "ApexMobiles Pvt Ltd",
    "Manufacturer_address": "19 Mobile Park",
    "Manufacturer_State": "Delhi",
    "Product_Category": "Mobiles",
    "Prouct_sub_Category": "Flagship Smartphone",
    "Product_Id": "MBP004",
    "Product_Name": "ApexMobiles Z Pro Max",
    "Product_Description": "Flagship smartphone with 12GB RAM and 256GB storage",
    "Unit_Price": 890.00,
    "Current_Stock": 340,
    "Lead_time_days": 6,
    "Total_orders": 540,
    "Total_units_supplied": 4200,
    "Return_Units": 85,
    "Response_Time_in_hrs": 10,
    "Ratings": 4.8
  },
  {
    "Manufacturer_id": "MB005",
    "Manufacturer_name": "FusionTech Devices",
    "Manufacturer_address": "67 Gadget Hub",
    "Manufacturer_State": "Gujarat",
    "Product_Category": "Mobiles",
    "Prouct_sub_Category": "Smartphone",
    "Product_Id": "MBP005",
    "Product_Name": "FusionTech Neo 5G",
    "Product_Description": "Mid-range 5G smartphone with fast charging",
    "Unit_Price": 380.00,
    "Current_Stock": 710,
    "Lead_time_days": 4,
    "Total_orders": 890,
    "Total_units_supplied": 7200,
    "Return_Units": 140,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "MB006",
    "Manufacturer_name": "SmartWave Electronics",
    "Manufacturer_address": "22 Tech Valley",
    "Manufacturer_State": "Punjab",
    "Product_Category": "Mobiles",
    "Prouct_sub_Category": "Gaming Smartphone",
    "Product_Id": "MBP006",
    "Product_Name": "SmartWave Gamer X",
    "Product_Description": "Gaming smartphone with high refresh rate display",
    "Unit_Price": 520.00,
    "Current_Stock": 480,
    "Lead_time_days": 5,
    "Total_orders": 720,
    "Total_units_supplied": 5800,
    "Return_Units": 110,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "MB007",
    "Manufacturer_name": "ZenithMobiles Corp",
    "Manufacturer_address": "31 Smart Street",
    "Manufacturer_State": "Rajasthan",
    "Product_Category": "Mobiles",
    "Prouct_sub_Category": "Smartphone",
    "Product_Id": "MBP007",
    "Product_Name": "ZenithMobiles Prime 6",
    "Product_Description": "6.7 inch smartphone with quad camera setup",
    "Unit_Price": 410.00,
    "Current_Stock": 650,
    "Lead_time_days": 4,
    "Total_orders": 940,
    "Total_units_supplied": 7600,
    "Return_Units": 150,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "MB008",
    "Manufacturer_name": "NextGen Communications",
    "Manufacturer_address": "54 Digital Plaza",
    "Manufacturer_State": "Uttar Pradesh",
    "Product_Category": "Mobiles",
    "Prouct_sub_Category": "Foldable Smartphone",
    "Product_Id": "MBP008",
    "Product_Name": "NextGen Fold X",
    "Product_Description": "Premium foldable smartphone with dual display",
    "Unit_Price": 1250.00,
    "Current_Stock": 190,
    "Lead_time_days": 7,
    "Total_orders": 260,
    "Total_units_supplied": 1900,
    "Return_Units": 35,
    "Response_Time_in_hrs": 12,
    "Ratings": 4.9
  },
  {
    "Manufacturer_id": "MB009",
    "Manufacturer_name": "EliteCell Technologies",
    "Manufacturer_address": "72 Innovation Park",
    "Manufacturer_State": "Haryana",
    "Product_Category": "Mobiles",
    "Prouct_sub_Category": "Smartphone",
    "Product_Id": "MBP009",
    "Product_Name": "EliteCell Vision 5G",
    "Product_Description": "6.6 inch 5G smartphone with AI camera",
    "Unit_Price": 399.00,
    "Current_Stock": 720,
    "Lead_time_days": 4,
    "Total_orders": 880,
    "Total_units_supplied": 7100,
    "Return_Units": 145,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "MB010",
    "Manufacturer_name": "BrightMobile Pvt Ltd",
    "Manufacturer_address": "18 Tech Road",
    "Manufacturer_State": "West Bengal",
    "Product_Category": "Mobiles",
    "Prouct_sub_Category": "Budget Smartphone",
    "Product_Id": "MBP010",
    "Product_Name": "BrightMobile Spark A1",
    "Product_Description": "Affordable smartphone with 5000mAh battery",
    "Unit_Price": 140.00,
    "Current_Stock": 1350,
    "Lead_time_days": 3,
    "Total_orders": 1750,
    "Total_units_supplied": 14200,
    "Return_Units": 310,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.2
  },
  {
    "Manufacturer_id": "MB011",
    "Manufacturer_name": "HyperLink Devices",
    "Manufacturer_address": "90 Mobile Hub",
    "Manufacturer_State": "Telangana",
    "Product_Category": "Mobiles",
    "Prouct_sub_Category": "Gaming Smartphone",
    "Product_Id": "MBP011",
    "Product_Name": "HyperLink Nitro 7",
    "Product_Description": "Gaming smartphone with cooling system",
    "Unit_Price": 560.00,
    "Current_Stock": 420,
    "Lead_time_days": 5,
    "Total_orders": 690,
    "Total_units_supplied": 5400,
    "Return_Units": 105,
    "Response_Time_in_hrs": 9,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "MB012",
    "Manufacturer_name": "CoreConnect Electronics",
    "Manufacturer_address": "44 Gadget Avenue",
    "Manufacturer_State": "Kerala",
    "Product_Category": "Mobiles",
    "Prouct_sub_Category": "Smartphone",
    "Product_Id": "MBP012",
    "Product_Name": "CoreConnect S9",
    "Product_Description": "Slim design smartphone with AMOLED display",
    "Unit_Price": 370.00,
    "Current_Stock": 640,
    "Lead_time_days": 4,
    "Total_orders": 820,
    "Total_units_supplied": 6700,
    "Return_Units": 120,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "MB013",
    "Manufacturer_name": "InfinityMobiles Ltd",
    "Manufacturer_address": "63 Digital Street",
    "Manufacturer_State": "Odisha",
    "Product_Category": "Mobiles",
    "Prouct_sub_Category": "Flagship Smartphone",
    "Product_Id": "MBP013",
    "Product_Name": "Infinity X Ultra",
    "Product_Description": "Flagship smartphone with 200MP camera",
    "Unit_Price": 950.00,
    "Current_Stock": 310,
    "Lead_time_days": 6,
    "Total_orders": 480,
    "Total_units_supplied": 3900,
    "Return_Units": 70,
    "Response_Time_in_hrs": 10,
    "Ratings": 4.8
  },
  {
    "Manufacturer_id": "MB014",
    "Manufacturer_name": "WaveMobile Industries",
    "Manufacturer_address": "28 Innovation Road",
    "Manufacturer_State": "Bihar",
    "Product_Category": "Mobiles",
    "Prouct_sub_Category": "Smartphone",
    "Product_Id": "MBP014",
    "Product_Name": "WaveMobile Prime 5",
    "Product_Description": "Dual SIM smartphone with fast charging",
    "Unit_Price": 310.00,
    "Current_Stock": 780,
    "Lead_time_days": 4,
    "Total_orders": 910,
    "Total_units_supplied": 7500,
    "Return_Units": 135,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "MB015",
    "Manufacturer_name": "TechSphere Communications",
    "Manufacturer_address": "91 Mobile Lane",
    "Manufacturer_State": "Jharkhand",
    "Product_Category": "Mobiles",
    "Prouct_sub_Category": "Foldable Smartphone",
    "Product_Id": "MBP015",
    "Product_Name": "TechSphere FlexPro",
    "Product_Description": "Premium foldable 5G smartphone",
    "Unit_Price": 1180.00,
    "Current_Stock": 210,
    "Lead_time_days": 7,
    "Total_orders": 260,
    "Total_units_supplied": 2000,
    "Return_Units": 32,
    "Response_Time_in_hrs": 12,
    "Ratings": 4.9
  },
  {
    "Manufacturer_id": "SH001",
    "Manufacturer_name": "PureCare Cosmetics",
    "Manufacturer_address": "12 Beauty Park",
    "Manufacturer_State": "Maharashtra",
    "Product_Category": "Shampoo",
    "Prouct_sub_Category": "Herbal Shampoo",
    "Product_Id": "SHP001",
    "Product_Name": "PureCare Aloe Fresh 200ml",
    "Product_Description": "Herbal aloe vera shampoo for smooth hair",
    "Unit_Price": 3.50,
    "Current_Stock": 8500,
    "Lead_time_days": 4,
    "Total_orders": 2100,
    "Total_units_supplied": 28000,
    "Return_Units": 320,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "SH002",
    "Manufacturer_name": "GlowNest FMCG",
    "Manufacturer_address": "45 Care Avenue",
    "Manufacturer_State": "Karnataka",
    "Product_Category": "Shampoo",
    "Prouct_sub_Category": "Anti-Dandruff Shampoo",
    "Product_Id": "SHP002",
    "Product_Name": "GlowNest Dandruff Control 180ml",
    "Product_Description": "Anti-dandruff shampoo with zinc formula",
    "Unit_Price": 4.20,
    "Current_Stock": 7200,
    "Lead_time_days": 5,
    "Total_orders": 1850,
    "Total_units_supplied": 24000,
    "Return_Units": 290,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "SH003",
    "Manufacturer_name": "NatureGlow Products",
    "Manufacturer_address": "88 Herbal Street",
    "Manufacturer_State": "Tamil Nadu",
    "Product_Category": "Shampoo",
    "Prouct_sub_Category": "Organic Shampoo",
    "Product_Id": "SHP003",
    "Product_Name": "NatureGlow Coconut Shine 250ml",
    "Product_Description": "Organic coconut shampoo for hair nourishment",
    "Unit_Price": 5.10,
    "Current_Stock": 6100,
    "Lead_time_days": 5,
    "Total_orders": 1600,
    "Total_units_supplied": 20500,
    "Return_Units": 210,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "SH004",
    "Manufacturer_name": "FreshBloom Cosmetics",
    "Manufacturer_address": "19 Wellness Park",
    "Manufacturer_State": "Delhi",
    "Product_Category": "Shampoo",
    "Prouct_sub_Category": "Moisturizing Shampoo",
    "Product_Id": "SHP004",
    "Product_Name": "FreshBloom Silk Moist 200ml",
    "Product_Description": "Moisturizing shampoo for dry hair",
    "Unit_Price": 3.80,
    "Current_Stock": 7900,
    "Lead_time_days": 4,
    "Total_orders": 1980,
    "Total_units_supplied": 26500,
    "Return_Units": 305,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.4
  },
  {
    "Manufacturer_id": "SH005",
    "Manufacturer_name": "HerbalEdge Ltd",
    "Manufacturer_address": "67 Organic Lane",
    "Manufacturer_State": "Kerala",
    "Product_Category": "Shampoo",
    "Prouct_sub_Category": "Herbal Shampoo",
    "Product_Id": "SHP005",
    "Product_Name": "HerbalEdge Neem Protect 220ml",
    "Product_Description": "Neem based herbal shampoo for scalp care",
    "Unit_Price": 4.00,
    "Current_Stock": 6700,
    "Lead_time_days": 5,
    "Total_orders": 1700,
    "Total_units_supplied": 22500,
    "Return_Units": 260,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.6
  },

  {
    "Manufacturer_id": "SH006",
    "Manufacturer_name": "AquaCare Personal",
    "Manufacturer_address": "22 Beauty Road",
    "Manufacturer_State": "Punjab",
    "Product_Category": "Shampoo",
    "Prouct_sub_Category": "Anti-Hairfall Shampoo",
    "Product_Id": "SHP006",
    "Product_Name": "AquaCare HairFall Defense 250ml",
    "Product_Description": "Strengthening shampoo to reduce hair fall",
    "Unit_Price": 4.75,
    "Current_Stock": 5400,
    "Lead_time_days": 5,
    "Total_orders": 1450,
    "Total_units_supplied": 19200,
    "Return_Units": 240,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.5
  },

  {
    "Manufacturer_id": "SH007",
    "Manufacturer_name": "EcoShine Naturals",
    "Manufacturer_address": "31 Green Avenue",
    "Manufacturer_State": "Rajasthan",
    "Product_Category": "Shampoo",
    "Prouct_sub_Category": "Organic Shampoo",
    "Product_Id": "SHP007",
    "Product_Name": "EcoShine Argan Smooth 200ml",
    "Product_Description": "Argan oil shampoo for silky smooth hair",
    "Unit_Price": 5.50,
    "Current_Stock": 4300,
    "Lead_time_days": 6,
    "Total_orders": 1320,
    "Total_units_supplied": 16500,
    "Return_Units": 180,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.7
  },

  {
    "Manufacturer_id": "SH008",
    "Manufacturer_name": "BrightCare FMCG",
    "Manufacturer_address": "54 Care Plaza",
    "Manufacturer_State": "Uttar Pradesh",
    "Product_Category": "Shampoo",
    "Prouct_sub_Category": "Kids Shampoo",
    "Product_Id": "SHP008",
    "Product_Name": "BrightCare Kids Gentle Wash 150ml",
    "Product_Description": "Tear-free shampoo specially formulated for kids",
    "Unit_Price": 3.20,
    "Current_Stock": 8800,
    "Lead_time_days": 4,
    "Total_orders": 2200,
    "Total_units_supplied": 29500,
    "Return_Units": 350,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "SH009",
    "Manufacturer_name": "SilkRoot Cosmetics",
    "Manufacturer_address": "72 Care Industrial Area",
    "Manufacturer_State": "Haryana",
    "Product_Category": "Shampoo",
    "Prouct_sub_Category": "Moisturizing Shampoo",
    "Product_Id": "SHP009",
    "Product_Name": "SilkRoot Hydrate Plus 300ml",
    "Product_Description": "Deep hydration shampoo for dry and frizzy hair",
    "Unit_Price": 5.80,
    "Current_Stock": 5200,
    "Lead_time_days": 5,
    "Total_orders": 1380,
    "Total_units_supplied": 17600,
    "Return_Units": 210,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "SH010",
    "Manufacturer_name": "UrbanGlow FMCG",
    "Manufacturer_address": "18 Beauty Circle",
    "Manufacturer_State": "West Bengal",
    "Product_Category": "Shampoo",
    "Prouct_sub_Category": "Anti-Dandruff Shampoo",
    "Product_Id": "SHP010",
    "Product_Name": "UrbanGlow Scalp Care 200ml",
    "Product_Description": "Clinically tested anti-dandruff shampoo",
    "Unit_Price": 4.40,
    "Current_Stock": 6900,
    "Lead_time_days": 4,
    "Total_orders": 1820,
    "Total_units_supplied": 23800,
    "Return_Units": 275,
    "Response_Time_in_hrs": 6,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "SH011",
    "Manufacturer_name": "HairNova Ltd",
    "Manufacturer_address": "90 Wellness Hub",
    "Manufacturer_State": "Telangana",
    "Product_Category": "Shampoo",
    "Prouct_sub_Category": "Color Protection Shampoo",
    "Product_Id": "SHP011",
    "Product_Name": "HairNova Color Shield 250ml",
    "Product_Description": "Protects hair color and adds shine",
    "Unit_Price": 6.20,
    "Current_Stock": 4100,
    "Lead_time_days": 6,
    "Total_orders": 1200,
    "Total_units_supplied": 15000,
    "Return_Units": 165,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.7
  },
  {
    "Manufacturer_id": "SH012",
    "Manufacturer_name": "GreenLeaf Care",
    "Manufacturer_address": "44 Herbal Plaza",
    "Manufacturer_State": "Kerala",
    "Product_Category": "Shampoo",
    "Prouct_sub_Category": "Herbal Shampoo",
    "Product_Id": "SHP012",
    "Product_Name": "GreenLeaf Hibiscus Repair 220ml",
    "Product_Description": "Hibiscus enriched shampoo for hair repair",
    "Unit_Price": 4.90,
    "Current_Stock": 4800,
    "Lead_time_days": 5,
    "Total_orders": 1420,
    "Total_units_supplied": 18000,
    "Return_Units": 200,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "SH013",
    "Manufacturer_name": "VelvetCare Cosmetics",
    "Manufacturer_address": "63 Shine Street",
    "Manufacturer_State": "Odisha",
    "Product_Category": "Shampoo",
    "Prouct_sub_Category": "Smoothening Shampoo",
    "Product_Id": "SHP013",
    "Product_Name": "VelvetCare Smooth Silk 200ml",
    "Product_Description": "Smoothening shampoo for frizz control",
    "Unit_Price": 4.60,
    "Current_Stock": 5600,
    "Lead_time_days": 5,
    "Total_orders": 1500,
    "Total_units_supplied": 19500,
    "Return_Units": 230,
    "Response_Time_in_hrs": 7,
    "Ratings": 4.5
  },
  {
    "Manufacturer_id": "SH014",
    "Manufacturer_name": "PureBloom Naturals",
    "Manufacturer_address": "28 Herbal Road",
    "Manufacturer_State": "Bihar",
    "Product_Category": "Shampoo",
    "Prouct_sub_Category": "Organic Shampoo",
    "Product_Id": "SHP014",
    "Product_Name": "PureBloom Tea Tree Fresh 250ml",
    "Product_Description": "Tea tree oil shampoo for oily scalp",
    "Unit_Price": 5.30,
    "Current_Stock": 4500,
    "Lead_time_days": 6,
    "Total_orders": 1250,
    "Total_units_supplied": 15800,
    "Return_Units": 175,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.6
  },
  {
    "Manufacturer_id": "SH015",
    "Manufacturer_name": "BrightRoots FMCG",
    "Manufacturer_address": "91 Care Lane",
    "Manufacturer_State": "Jharkhand",
    "Product_Category": "Shampoo",
    "Prouct_sub_Category": "Anti-Hairfall Shampoo",
    "Product_Id": "SHP015",
    "Product_Name": "BrightRoots Strength Plus 300ml",
    "Product_Description": "Keratin enriched anti-hairfall shampoo",
    "Unit_Price": 5.90,
    "Current_Stock": 3900,
    "Lead_time_days": 6,
    "Total_orders": 1180,
    "Total_units_supplied": 14900,
    "Return_Units": 160,
    "Response_Time_in_hrs": 8,
    "Ratings": 4.7
  }
]

df = pd.DataFrame(data)

# %%
# ------------------------------------------------
# 2. FEATURE ENGINEERING
# ------------------------------------------------
# df["available_stock"] = df["current_stock"] - df["reserved_stock"]
# df["stock_utilization"] = df["available_stock"] / (df["current_stock"] + 1)

# features = [
#     "price",
#     "lead_time_days",
#     "available_stock",
#     "stock_utilization",
#     "on_time_delivery_rate",
#     "order_fulfillment_rate",
#     "defect_rate",
#     "return_rate",
#     "avg_response_time_hrs",
#     "compliance_score"
# ]

# X = df[features]
# y = df["successful_order"]

# %%
# ------------------------------------------------
# 3. TRAIN ML MODEL
# ------------------------------------------------
# model = RandomForestRegressor(
#     n_estimators=150,
#     max_depth=6,
#     random_state=42
# )

# model.fit(X, y)

# %%
# ------------------------------------------------
# 4. PREDICT RELIABILITY SCORE
# ------------------------------------------------
# df["reliability_score"] = model.predict(X)

# # Normalize between 0–1
# df["reliability_score"] = (
#     df["reliability_score"] - df["reliability_score"].min()
# ) / (df["reliability_score"].max() - df["reliability_score"].min())

# %%
# Assume worst acceptable lead time = 30 days
df["delivery_score"] = 1 - (df["Lead_time_days"] / 30)
df["delivery_score"] = df["delivery_score"].clip(0, 1)

df["quantity_score"] = (
    (df["Current_Stock"] - df["Current_Stock"].min()) /
    (df["Current_Stock"].max() - df["Current_Stock"].min())
)

df["cost_score"] = 1 - (
    (df["Unit_Price"] - df["Unit_Price"].min()) /
    (df["Unit_Price"].max() - df["Unit_Price"].min())
)

df["order_fulfillment_rate"] = (
    df["Total_units_supplied"] / df["Total_orders"]
)

df["return_rate"] = (
    df["Return_Units"] / df["Total_units_supplied"]
)

df["quality_score"] = (
    0.7 * df["order_fulfillment_rate"] +
    0.3 * (1 - df["return_rate"])
)

df["avg_response_time_rate"] = 1 - (df["Response_Time_in_hrs"] / 48)
df["avg_response_time_rate"] = df["avg_response_time_rate"].clip(0, 1)

df["compliance_rate"] = df["Ratings"] / 5

df["rating_score"] = (
    0.6 * df["compliance_rate"] +
    0.4 * df["avg_response_time_rate"]
)

# %%
# ------------------------------------------------
# RELIABILITY SCORE CALCULATION (YOUR FORMULA)
# ------------------------------------------------
df["reliability_score"] = (
    0.25 * df["delivery_score"] +
    0.20 * df["quantity_score"] +
    0.15 * df["cost_score"] +
    0.25 * df["quality_score"] +
    0.15 * df["rating_score"]
)

## should add price in reliability score

# %%
# ------------------------------------------------
# 5. FINAL RANKING
# ------------------------------------------------
# ranked = df.sort_values("reliability_score", ascending=False)

# print("\n=== Manufacturer Recommendation Ranking ===\n")
# print(ranked[[
#     "manufacturer_id",
#     "product_id",
#     "available_stock",
#     "reliability_score"
# ]])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df["product_text"] = (
    df["Product_Name"] + " " + df["Product_Description"]
)

vectorizer = TfidfVectorizer(stop_words="english")
product_vectors = vectorizer.fit_transform(df["product_text"])

# %%
def recommend_supplier_by_search(
    search_query,
    required_qty,
    similarity_threshold=0.2,
    top_n=4
):
    # Vectorize search query
    search_vector = vectorizer.transform([search_query])

    # Compute similarity
    similarities = cosine_similarity(search_vector, product_vectors)[0]
    df["similarity_score"] = similarities

    # Filter relevant products
    filtered = df[
        (df["similarity_score"] >= similarity_threshold) &
        (df["Current_Stock"] >= required_qty)
    ]

    if filtered.empty:
        print("❌ No matching products found for your search")
        return

    # Rank suppliers
    ranked = filtered.sort_values(
        by=["Ratings", "Unit_Price", "Lead_time_days"],
        ascending=[False, True, True]
    )

    # Take TOP 4
    top_recommended = ranked.head(top_n)

    print("\n🔍 Search:", search_query)
    print(f"✅ Top {len(top_recommended)} Recommended Suppliers:\n")

    for i, (_, row) in enumerate(top_recommended.iterrows(), start=1):
        print(
            f"{i}. Manufacturer: {row['Manufacturer_id']} | "
            f"Product: {row['Product_Name']} | "
            f"Price: ₹{row['Unit_Price']} | "
            f"Delivery: {row['Lead_time_days']} days | "
            f"Stock: {row['Current_Stock']} | "
            f"Rating: {row['Ratings']} "
            f"Reliability Score: {row['reliability_score']}"
        )

# %%
recommend_supplier_by_search(
    search_query="led bulb",
    required_qty=500
)
# Out:
# 🔍 Search: led bulb
# ✅ Top 2 Recommended Suppliers:
#
# 1. Manufacturer: L001 | Product: GlowTech 9W Eco LED | Price: ₹4.5 | Delivery: 3 days | Stock: 8500 | Rating: 4.4 Reliability Score: 2.943457451089086
# 2. Manufacturer: TV001 | Product: VisionTech LED 32" HD | Price: ₹180.0 | Delivery: 5 days | Stock: 520 | Rating: 4.4 Reliability Score: 1.9960529846169148
